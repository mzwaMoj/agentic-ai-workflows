# %% [markdown]
# # LlamaIndex RAG with OpenAI - Updated for Standard OpenAI API
#
# ## 🔄 Migration Notice
# This notebook has been migrated from Azure OpenAI to **standard OpenAI API**.
#
# ### Required Environment Variables:
# ```bash
# OPENAI_API_KEY=your-openai-api-key
# OPENAI_MODEL=gpt-4.1  # or your preferred model
# OPENAI_EMBEDDING_MODEL=text-embedding-3-small  # or text-embedding-3-large
# ```
#
# ### Key Changes:
# - ✅ Using `llama-index-embeddings-openai` instead of `llama-index-embeddings-azure-openai`
# - ✅ Using `llama-index-llms-openai` instead of `llama-index-llms-azure-openai`
# - ✅ Simplified configuration - no Azure endpoints, deployments, or API versions needed
# - ✅ All embedding operations now use `https://api.openai.com/v1/embeddings`
#
# ### Installation:
# ```bash
# pip install llama-index-embeddings-openai llama-index-llms-openai
# ```
#
# ---

# %% [markdown]
# # LlamaIndex Kernel Crash Troubleshooting Guide
#
# ## 🚨 Kernel Crash at Step 3 (LlamaIndex Import)
#
# Your kernel is crashing during the LlamaIndex import phase. This is a common issue that can be caused by:
#
# ### **Most Common Causes:**
# 1. **Package Version Conflicts** - Incompatible versions of LlamaIndex components
# 2. **Missing Dependencies** - Some required packages are not installed
# 3. **Memory Issues** - Insufficient memory for loading large models
# 4. **Environment Conflicts** - Multiple Python environments or conflicting packages
#
# ### **Troubleshooting Steps:**
#
# #### **Step 1: Run Package Diagnostic**
# Run the "PACKAGE DIAGNOSTIC & INSTALLATION CELL" below first.
#
# #### **Step 2: Test Minimal Imports**
# Run the "MINIMAL IMPORT TEST" to identify which specific import is failing.
#
# #### **Step 3: Clean Installation (if needed)**
# If imports still fail, run the "ALTERNATIVE LLAMAINDEX INSTALLATION" cell.
#
# #### **Step 4: Restart Kernel**
# After any package installation, **always restart your kernel**.
#
# #### **Step 5: Use Kernel-Safe Query**
# Finally, use the "KERNEL-SAFE LOCAL QUERY" cell which includes memory management.
#
# ### **Expected Flow:**
# 1. ✅ Environment variables found (Step 2) - **COMPLETED**
# 2. ❌ LlamaIndex imports (Step 3) - **FAILING HERE**
# 3. ⏸️ Azure OpenAI configuration (Step 4) - Pending
# 4. ⏸️ ChromaDB connection (Step 5) - Pending
# 5. ⏸️ Query execution (Step 6) - Pending
#
# ---

# %%
# PACKAGE DIAGNOSTIC & INSTALLATION CELL
# Run this first to diagnose and fix LlamaIndex import issues

import sys
import subprocess
import importlib
import pkg_resources
from packaging import version

def check_and_install_packages():
    """
    Comprehensive package check and installation for LlamaIndex ecosystem
    """
    
    print("🔍 Python Environment Information:")
    print(f"Python Version: {sys.version}")
    print(f"Python Executable: {sys.executable}")
    print(f"Platform: {sys.platform}")
    print("="*60)
    
    # Required packages with their correct names
    required_packages = {
        'llama-index': '0.11.20',  # Core package
        'llama-index-core': None,   # Core components
        'llama-index-embeddings-azure-openai': None,  # Azure OpenAI embeddings
        'llama-index-llms-azure-openai': None,  # Azure OpenAI LLM
        'llama-index-vector-stores-chroma': None,  # Chroma vector store
        'chromadb': '0.4.24',  # ChromaDB
        'openai': '1.3.0',  # OpenAI client
        'httpx': None,  # HTTP client
        'python-dotenv': None,  # Environment variables
    }
    
    print("🔍 Checking installed packages...")
    installed_packages = {}
    missing_packages = []
    outdated_packages = []
    
    # Check what's currently installed
    for package_name, min_version in required_packages.items():
        try:
            # Try to get the installed version
            installed_version = pkg_resources.get_distribution(package_name).version
            installed_packages[package_name] = installed_version
            
            print(f"✅ {package_name}: {installed_version}")
            
            # Check if version is adequate
            if min_version and version.parse(installed_version) < version.parse(min_version):
                outdated_packages.append((package_name, installed_version, min_version))
                
        except pkg_resources.DistributionNotFound:
            print(f"❌ {package_name}: NOT INSTALLED")
            missing_packages.append(package_name)
        except Exception as e:
            print(f"⚠️ {package_name}: Error checking - {e}")
            missing_packages.append(package_name)
    
    print("\n" + "="*60)
    
    # Report issues
    if missing_packages:
        print(f"❌ Missing packages: {missing_packages}")
    
    if outdated_packages:
        print(f"⚠️ Outdated packages: {outdated_packages}")
    
    if not missing_packages and not outdated_packages:
        print("✅ All required packages are installed with adequate versions!")
        return True
    
    # Install/upgrade packages
    packages_to_install = missing_packages + [pkg[0] for pkg in outdated_packages]
    
    if packages_to_install:
        print(f"\n🚀 Installing/upgrading packages: {packages_to_install}")
        
        for package in packages_to_install:
            try:
                print(f"Installing {package}...")
                subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", package])
                print(f"✅ {package} installed successfully")
            except subprocess.CalledProcessError as e:
                print(f"❌ Failed to install {package}: {e}")
                return False
    
    return True

def test_imports():
    """
    Test critical imports one by one to identify the problem
    """
    print("\n🧪 Testing imports one by one...")
    
    imports_to_test = [
        ("chromadb", "import chromadb"),
        ("llama_index.core", "from llama_index.core import Settings"),
        ("llama_index.vector_stores.chroma", "from llama_index.vector_stores.chroma import ChromaVectorStore"),
        ("llama_index.core.storage", "from llama_index.core import StorageContext, VectorStoreIndex"),
        ("llama_index.embeddings.azure_openai", "from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding"),
        ("llama_index.llms.azure_openai", "from llama_index.llms.azure_openai import AzureOpenAI"),
    ]
    
    failed_imports = []
    
    for name, import_statement in imports_to_test:
        try:
            exec(import_statement)
            print(f"✅ {name}: SUCCESS")
        except Exception as e:
            print(f"❌ {name}: FAILED - {e}")
            failed_imports.append((name, str(e)))
    
    if failed_imports:
        print(f"\n❌ Failed imports detected: {len(failed_imports)}")
        for name, error in failed_imports:
            print(f"  - {name}: {error}")
        return False
    else:
        print("\n✅ All imports successful!")
        return True

# Run the diagnostics
print("🚀 Starting Package Diagnostic...")
packages_ok = check_and_install_packages()

if packages_ok:
    print("\n" + "="*60)
    imports_ok = test_imports()
    
    if imports_ok:
        print("\n🎉 SUCCESS! All packages installed and imports working.")
        print("You can now proceed to run the local index query.")
    else:
        print("\n❌ Import issues detected. Check the error messages above.")
else:
    print("\n❌ Package installation issues detected.")

print("\n🔄 Please restart your kernel after running this cell if packages were installed.")
# Out:
# 🚀 Starting Package Diagnostic...
# 🔍 Python Environment Information:
# Python Version: 3.12.0 (v3.12.0:0fb18b02c8, Oct  2 2023, 09:45:56) [Clang 13.0.0 (clang-1300.0.29.30)]
# Python Executable: /Users/mzwandilemhlongo/Desktop/Data Science/PersonalProjects/ai-powered-analysis/text2sql/ai-analyst-agent/.venv/bin/python
# Platform: darwin
# ============================================================
# 🔍 Checking installed packages...
# ✅ llama-index: 0.14.6
# ✅ llama-index-core: 0.14.6
# ✅ llama-index-embeddings-azure-openai: 0.4.1
# ✅ llama-index-llms-azure-openai: 0.4.2
# ✅ llama-index-vector-stores-chroma: 0.5.3
# ✅ chromadb: 1.3.0
# ✅ openai: 1.109.1
# ✅ httpx: 0.28.1
# ✅ python-dotenv: 1.2.1
#
# ============================================================
# ✅ All required packages are installed with adequate versions!
#
# ============================================================
#
# 🧪 Testing imports one by one...
# ✅ chromadb: SUCCESS
# ✅ llama_index.core: SUCCESS
# ✅ llama_index.vector_stores.chroma: SUCCESS
# ✅ llama_index.core.storage: SUCCESS
# ✅ llama_index.embeddings.azure_openai: SUCCESS
# ✅ llama_index.llms.azure_openai: SUCCESS
#
# ✅ All imports successful!
#
# 🎉 SUCCESS! All packages installed and imports working.
# You can now proceed to run the local index query.
#
# 🔄 Please restart your kernel after running this cell if packages were installed.

# %%
# MINIMAL IMPORT TEST
# Run this to test imports without any complex logic

print("🧪 Testing minimal imports...")

try:
    print("Testing basic imports...")
    import os
    import sys
    print("✅ Basic imports OK")
    
    print("Testing ChromaDB...")
    import chromadb
    print(f"✅ ChromaDB version: {chromadb.__version__}")
    
    print("Testing LlamaIndex core...")
    from llama_index.core import Settings
    print("✅ LlamaIndex core OK")
    
    print("Testing LlamaIndex vector store...")
    from llama_index.vector_stores.chroma import ChromaVectorStore
    print("✅ ChromaVectorStore OK")
    
    print("Testing LlamaIndex storage...")
    from llama_index.core import StorageContext, VectorStoreIndex
    print("✅ StorageContext and VectorStoreIndex OK")
    
    print("Testing Azure OpenAI embedding...")
    from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
    print("✅ AzureOpenAIEmbedding OK")
    
    print("Testing Azure OpenAI LLM...")
    from llama_index.llms.azure_openai import AzureOpenAI
    print("✅ AzureOpenAI LLM OK")
    
    print("\n🎉 ALL IMPORTS SUCCESSFUL!")
    print("You can now proceed with the local index query.")
    
except Exception as e:
    print(f"\n❌ IMPORT FAILED: {e}")
    print(f"Error type: {type(e).__name__}")
    import traceback
    print("\nFull traceback:")
    traceback.print_exc()
    
    print("\n🔧 RECOMMENDATIONS:")
    print("1. Run the package diagnostic cell above")
    print("2. If that fails, run the clean installation cell")
    print("3. Restart your kernel after any installations")
    print("4. Check that you're using the correct Python environment")
# Out:
# 🧪 Testing minimal imports...
# Testing basic imports...
# ✅ Basic imports OK
# Testing ChromaDB...
# ✅ ChromaDB version: 1.3.0
# Testing LlamaIndex core...
# ✅ LlamaIndex core OK
# Testing LlamaIndex vector store...
# ✅ ChromaVectorStore OK
# Testing LlamaIndex storage...
# ✅ StorageContext and VectorStoreIndex OK
# Testing Azure OpenAI embedding...
# ✅ AzureOpenAIEmbedding OK
# Testing Azure OpenAI LLM...
# ✅ AzureOpenAI LLM OK
#
# 🎉 ALL IMPORTS SUCCESSFUL!
# You can now proceed with the local index query.

# %%
# Utility function to initialize LlamaIndex Settings
# Run this cell first before any local index querying

def initialize_llamaindex_settings():
    """
    Initialize LlamaIndex global settings with OpenAI configuration.
    This MUST be called before querying from local index.
    """
    import os
    from dotenv import load_dotenv, find_dotenv
    from llama_index.core import Settings
    from llama_index.embeddings.openai import OpenAIEmbedding
    from llama_index.llms.openai import OpenAI as LlamaIndexOpenAI
    import warnings
    
    warnings.filterwarnings("ignore")
    load_dotenv(find_dotenv())
    
    # OpenAI configuration
    OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
    OPENAI_MODEL = os.environ.get("OPENAI_MODEL", "gpt-4o")
    OPENAI_EMBEDDING_MODEL = os.environ.get("OPENAI_EMBEDDING_MODEL", "text-embedding-3-small")
    
    # Set up LLM with standard OpenAI
    llm = LlamaIndexOpenAI(
        api_key=OPENAI_API_KEY,
        model=OPENAI_MODEL,
    )
    
    # Set up embedding model with standard OpenAI
    embedding_model = OpenAIEmbedding(
        model=OPENAI_EMBEDDING_MODEL,
        api_key=OPENAI_API_KEY,
        api_base="https://api.openai.com/v1",
    )
    
    # Set global Settings
    Settings.llm = llm
    Settings.embed_model = embedding_model
    
    print("✅ LlamaIndex Settings initialized successfully with OpenAI!")
    return llm, embedding_model

# Initialize settings
llm, embedding_model = initialize_llamaindex_settings()
# Out:
# ✅ LlamaIndex Settings initialized successfully with OpenAI!

# %% [markdown]
# # Metadata RAG

# %% [markdown]
# ## Text Embeddings

# %% [markdown]
# ## LlamaIndex RAG

# %%
import os
from dotenv import load_dotenv, find_dotenv
import warnings
warnings.filterwarnings("ignore")
load_dotenv(find_dotenv())

# Note: SSL/HTTP configuration not needed for standard OpenAI API
# Out:
# True

# %%
import os
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI as LlamaIndexOpenAI
from llama_index.core.query_engine import RetrieverQueryEngine
import logging
import sys

# %%
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
OPENAI_MODEL = os.environ.get("OPENAI_MODEL")
OPENAI_EMBEDDING_MODEL = os.environ.get("OPENAI_EMBEDDING_MODEL", "text-embedding-3-large")

# Set up LLM with standard OpenAI
llm = LlamaIndexOpenAI(
    api_key=OPENAI_API_KEY,
    model=OPENAI_MODEL,
)

# Set up embedding model with standard OpenAI
embedding_model = OpenAIEmbedding(
    model=OPENAI_EMBEDDING_MODEL,
    api_key=OPENAI_API_KEY,
    api_base="https://api.openai.com/v1",
)

Settings.llm = llm
Settings.embed_model = embedding_model

# %%
# Define file-specific metadata

doc_sample_file = r"/Users/mzwandilemhlongo/Desktop/Data Science/PersonalProjects/ai-powered-analysis/text2sql/ai-analyst-agent/table_metadata/sample_file.txt"

file_paths = [ doc_sample_file]

def get_metadata_for_files(file_paths):
    # Create a map of file path to custom metadata
    file_metadata_map = {
        
        doc_sample_file: {
            "category": "sample File ",
            "year": "2025-11-01",
            "department": "Finance", 
            "author": "Mzwandile Mhlongo",
            "confidentiality": "high",
            "description": "This file is only used for testing"
        },
    }
    
    # The function that SimpleDirectoryReader will call
    def file_metadata_func(file_path):
        # Get predefined metadata if available, otherwise return basic metadata
        if file_path in file_metadata_map:
            return file_metadata_map[file_path]
        else:
            return {
                "source": file_path,
                "file_type": os.path.splitext(file_path)[1],
                "confidentiality": "unknown"
            }
    
    return file_metadata_func

# Create reader with specific files and their metadata
documents = SimpleDirectoryReader(
    input_files=file_paths,
    file_metadata=get_metadata_for_files(file_paths)
).load_data()

# Create index and query engine as before
index = VectorStoreIndex.from_documents(documents)
# Out:
# 2025-11-01 08:10:21,544 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
# Query From Local Index
import chromadb
import sys
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import VectorStoreIndex, StorageContext  # Added Settings import
                                
# initialize client
index_path = r"..\index\chroma_db"
db = chromadb.PersistentClient(path=index_path)

# get collection
chroma_collection = db.get_or_create_collection("sql_tables_metadata")

# assign chroma as the vector_store to the context
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# load your index from stored vectors
index_local = VectorStoreIndex.from_vector_store(
                                            vector_store = vector_store, 
                                            storage_context=storage_context
                                        )

# create a query engine
local_query_engine = index_local.as_query_engine(similarity_top_k=10)

def generate_response(query):
    answer = local_query_engine.query(query)
    print("\n**Query:**\n", query)
    print("\n**Answer:**\n", answer)
    print("\n**Source:**\n", answer.get_formatted_sources())
    
    # Optionally print metadata from sources to verify it's working
    print("\n**Source Metadata:**")
    for source_node in answer.source_nodes:
        print(f"- {source_node.node.metadata}")

generate_response("generate the full table details without intepreting or editing anything: customer information full table details")
# Out:
# 2025-11-01 08:10:28,513 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# **Query:**
#  generate the full table details without intepreting or editing anything: customer information full table details
#
# **Answer:**
#  Empty Response
#
# **Source:**
#
#
# **Source Metadata:**

# %%
# Define file-specific metadata

doc_transactions_path = r"../table_metadata/metadata_transaction_history.txt"
doc_customer_info_path = r"../table_metadata/metadata_customer_information.txt"
doc_crs_accountreport_path = r"../table_metadata/metadata_crs_account_report.txt"
doc_crs_countrycode_path = r"../table_metadata/metadata_crs_countrycode.txt"
doc_crs_messagespec_path = r"../table_metadata/metadata_crs_messagespec.txt"

file_paths = [doc_transactions_path, 
            doc_customer_info_path, 
            doc_crs_accountreport_path, 
            doc_crs_countrycode_path, 
            doc_crs_messagespec_path]

def get_metadata_for_files(file_paths):
    # Create a map of file path to custom metadata
    file_metadata_map = {
        
        doc_transactions_path: {
            "category": "transaction history table",
            "year": "2025-07-20",
            "department": "Finance", 
            "author": "Mzwandile Mhlongo",
            "confidentiality": "high",
            "description": "Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases"
        },
        doc_customer_info_path: {
            "category": "customer information table",
            "year": "2025-07-20",
            "department": "Finance", 
            "author": "Mzwandile Mhlongo",
            "confidentiality": "high",
            "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers"
        },
        doc_crs_accountreport_path: {
            "category": "Common Reporting Standard (CRS) Account Reporting",
            "year": "2025-07-20",
            "department": "Finance",
            "author": "Mzwandile Mhlongo",
            "confidentiality": "low",
            "description": "Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency"
        },
        doc_crs_countrycode_path: {
            "category": "Common Reporting Standard (CRS) Country Codes",
            "year": "2025-07-20",
            "department": "Finance",
            "author": "Mzwandile Mhlongo",
            "confidentiality": "low",
            "description": "Comprehensive country code reference for **Common Reporting Standard (CRS)** reporting. This table provides essential mappings between various country code formats, ensuring accurate and consistent country identification across CRS data. It is based on the **ISO 3166-1 alpha-2 standard"
        },
        doc_crs_messagespec_path: {
            "category": "Common Reporting Standard (CRS) Message Specification",
            "year": "2025-07-20",
            "department": "Finance",
            "author": "Mzwandile Mhlongo",
            "confidentiality": "low",
            "description": "This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages"
        },
    }
    
    # The function that SimpleDirectoryReader will call
    def file_metadata_func(file_path):
        # Get predefined metadata if available, otherwise return basic metadata
        if file_path in file_metadata_map:
            return file_metadata_map[file_path]
        else:
            return {
                "source": file_path,
                "file_type": os.path.splitext(file_path)[1],
                "confidentiality": "unknown"
            }
    
    return file_metadata_func

# Create reader with specific files and their metadata
documents = SimpleDirectoryReader(
    input_files=file_paths,
    file_metadata=get_metadata_for_files(file_paths)
).load_data()

# Create index and query engine as before
index = VectorStoreIndex.from_documents(documents)
# Out:
# 2025-10-31 06:22:18,276 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
# query engine
query_engine = index.as_query_engine(
    similarity_top_k=10
)

# %%
def generate_response(query):
    answer = query_engine.query(query)
    print("\n**Query:**\n", query)
    print("\n**Answer:**\n", answer)
    print("\n**Source:**\n", answer.get_formatted_sources())
    
    # Optionally print metadata from sources to verify it's working
    print("\n**Source Metadata:**")
    for source_node in answer.source_nodes:
        print(f"- {source_node.node.metadata}")

# %%
generate_response("generate the full table details without intepreting or editing anything: customer information full table details")
# Out:
# 2025-10-31 06:22:34,044 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-10-31 06:23:17,973 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-10-31 06:23:17,973 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# **Query:**
#  generate the full table details without intepreting or editing anything: customer information full table details
#
# **Answer:**
#  Table: [dbo].[customer_information]
# Database: SQL Server (master)
# Schema: dbo
# Primary Key: id
# Description: Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
#
# Columns:
#
# - id (int)
#   - Description: Unique customer identifier, 8-digit number
#   - Range: 10000000 to 99999999
#   - Examples: 10474206, 10962741, 13765547
#   - Rules: Auto-generated unique identifier for each customer
#
# - full_name (nvarchar)
#   - Description: Customer's complete name (first and last name)
#   - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
#   - Rules: Required field, contains customer's legal name
#
# - email (nvarchar)
#   - Description: Customer's email address for communication
#   - Examples: nelsoneddie@example.net, dillonjodi@example.net
#   - Rules: Must be valid email format, used for notifications
#
# - phone_number (nvarchar)
#   - Description: Customer's contact phone number
#   - Examples: +1-555-123-4567, (555) 987-6543
#   - Rules: Various formats accepted, primary contact method
#
# - address (nvarchar)
#   - Description: Customer's physical address (street, city, state, zip)
#   - Examples: 123 Main St, Anytown, ST 12345
#   - Rules: Complete postal address for correspondence
#
# - account_number (nvarchar)
#   - Description: Bank account number associated with the customer
#   - Examples: 1234567890, 9876543210
#   - Rules: 10-digit unique account identifier
#
# - account_type (nvarchar)
#   - Description: Type of bank account held by the customer
#   - Valid Values: Savings, Cheque, Business
#   - Examples: Savings, Cheque, Business
#   - Rules: Determines account features and limitations
#
# - balance (decimal)
#   - Description: Current account balance in local currency
#   - Range: 100.00 to 50000.00
#   - Examples: 8383.72, 19437.26, 45030.79
#   - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# - gender (nvarchar)
#   - Description: Customer's gender identification
#   - Valid Values: Male, Female
#   - Examples: Male, Female
#   - Rules: Used for demographic analysis and targeted marketing
#
# - age (int)
#   - Description: Customer's age in years
#   - Range: 18 to 75
#   - Examples: 61, 30, 64
#   - Rules: Must be 18+ to open account, affects product eligibility
#
# - occupation (nvarchar)
#   - Description: Customer's current job title or profession
#   - Examples: English as a second language teacher, Engineering geologist, Information systems manager
#   - Rules: Used for risk assessment and income verification
#
# - income (decimal)
#   - Description: Customer's annual income in local currency
#   - Range: 20000.00 to 150000.00
#   - Examples: 45000.0, 32000.0, 85000.0
#   - Rules: Used for loan eligibility and credit limit determination
#
# - income_source (nvarchar)
#   - Description: Primary source of customer's income
#   - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
#   - Examples: Employment, Self-employment, Business
#   - Rules: Affects income stability assessment for lending
#
# - income_category (nvarchar)
#   - Description: Income classification based on amount
#   - Valid Values: Low, Medium, High
#   - Examples: Low, Medium, High
#   - Rules: Determines product offerings and credit limits
#     - Calculation rule: Low: <30K, Medium: 30K-70K, High: >70K
#
# - previous_loans_count (int)
#   - Description: Number of previous loans taken by the customer
#   - Range: 0 to 5
#   - Examples: 0, 2, 5
#   - Rules: Higher count may affect future loan approval
#
# - credit_score (int)
#   - Description: Customer's credit score based on credit history
#   - Range: 300 to 850
#   - Examples: 718, 807, 511
#   - Rules: Primary factor in loan approval and interest rate determination
#
# - loan_eligible (bit)
#   - Description: Boolean indicating if customer is eligible for loans
#   - Valid Values: 0, 1
#   - Examples: 1, 0
#   - Rules: Determines access to lending products
#     - Calculation rule: loan_eligible = 1 if credit_score >= 580, else 0
#
# - eligible_loan_amount (decimal)
#   - Description: Maximum loan amount customer is eligible for
#   - Examples: 25000.0, 50000.0, 100000.0
#   - Rules: Sets upper limit for loan applications
#
# - loan_amount_applied_for (decimal)
#   - Description: Amount of loan currently applied for or received
#   - Examples: 15000.0, 30000.0, 0.0
#   - Rules: Cannot exceed eligible_loan_amount, 0 if no loan application
#   - Constraint: loan_amount_applied_for <= eligible_loan_amount
#
# - loan_status (nvarchar)
#   - Description: Current status of loan application or existing loan
#   - Valid Values: Pending, Approved, Active, Closed, None
#   - Examples: Active, Pending, Approved
#   - Rules: NULL if no loan application
#
# - loan_tenure (int)
#   - Description: Loan repayment period in months
#   - Range: 6 to 60 months
#   - Examples: 12, 24, 60
#   - Rules: Longer tenure increases interest rate, NULL if no loan
#
# - loan_interest_rate (decimal)
#   - Description: Annual interest rate for the loan as a percentage
#   - Range: 3.50 to 20.00
#   - Examples: 7.5, 12.25, 15.0
#   - Rules: NULL if no loan, calculated using risk-based pricing
#     - Constraint/Calculation: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# - loan_purpose (nvarchar)
#   - Description: Reason for taking the loan
#   - Valid Values: Home, Education, Vehicle, Personal, Business
#   - Examples: Home, Education, Vehicle
#   - Rules: Required for loan applications, affects interest rates
#
# - loan_application_date (datetime)
#   - Description: Date when loan application was submitted
#   - Examples: 2023-05-15 10:30:00, 2024-01-20 14:45:00
#   - Rules: NULL if no loan application, within last 2 years
#
# - last_login (datetime)
#   - Description: Last time customer accessed online banking
#   - Examples: 2025-06-08 09:15:00, 2025-06-07 18:30:00
#   - Rules: Used to track customer engagement and activity
#
# - product_holding (nvarchar)
#   - Description: JSON array of bank products held by the customer
#   - Examples: ["Checking Account", "Overdraft Protection", "Foreign Currency Exchange"], ["Investment Advisory Services"], ["Home Mortgages", "Insurance Products", "Savings Account"]
#   - Rules: Determines cross-selling opportunities and customer value
#
# - no_product_holding (int)
#   - Description: Count of products currently held by the customer
#   - Range: 1 to 15
#   - Examples: 3, 1, 9
#   - Rules: Higher count indicates deeper customer relationship
#     - Calculation rule: no_product_holding is calculated from product_holding as COUNT of JSON array items
#
# - entrenchment_score (decimal)
#   - Description: Percentage of total available products held by customer
#   - Range: 0.00 to 100.00
#   - Examples: 13.04, 4.35, 39.13
#   - Rules: Higher score indicates stronger customer relationship and retention likelihood
#     - Calculation rule: (no_product_holding / 23) * 100
#
# Key Relationships & Rules:
#
# - loan_eligible is calculated from credit_score: loan_eligible = 1 if credit_score >= 580, else 0
# - income_category is calculated from income: Low: <30K, Medium: 30K-70K, High: >70K
# - no_product_holding is calculated from product_holding: COUNT of JSON array items
# - entrenchment_score is calculated from no_product_holding: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# Notes: All rules, ranges, valid values, examples, calculations and constraints are enforced as described for data integrity and product/loan eligibility determination.
#
# **Source:**
#  > Source (Doc id: 92287580-906e-4f11-8657-f63f00c8cf1f): <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: 32c64f03-8845-4f95-b2f5-8f3127b39622): 00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer r...
#
# > Source (Doc id: bf74eda0-1740-4a1b-9f5d-d4d7ecb0fb1e): <begin transaction history metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: 246aee3c-aff1-4dac-8427-13962a9d481a): ?####
#
# **merchant_name** (nvarchar)
# - Description: Name of merchant for purchase and payment tran...
#
# > Source (Doc id: ad7051ae-1f9b-4ff9-adf9-d624b3c73e8b): Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limit...
#
# > Source (Doc id: 6eb486eb-d967-4508-8868-cfdc741fe85c): - **Country Code Validation**: `ResCountryCode4`, `CountryCode5`, and `issuedBy7` must all contai...
#
# > Source (Doc id: cae61a75-8eb7-4fc1-8709-495ef273626e): <begin crs account report metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Datab...
#
# > Source (Doc id: c10124ed-0ba1-48e1-8402-1d179fe19c0f): Provides essential context for the structure of the `AccountNumber`.
#
# **ClosedAccount** (bit)
# - D...
#
# > Source (Doc id: 87b44227-4e41-4837-a08c-99796cb23802): - Examples: `MSGREFID-2024-GH-001`, `MSGREFID-ABC-2024-002`
# - Rules: **Mandatory**. Must be uniqu...
#
# > Source (Doc id: 29650249-fd41-4b1b-9f11-5662b9a62c48): Required when `AcctHolderType` is `CRS101` and `nameType` is `OECD201`. Can be `NULL` if `AcctHol...
#
# **Source Metadata:**
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Message Specification', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}

# %% [markdown]
# ## Persist the index to disk

# %%
import os
from dotenv import load_dotenv, find_dotenv
import warnings
warnings.filterwarnings("ignore")
load_dotenv(find_dotenv())

import chromadb
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.core.query_engine import RetrieverQueryEngine

# Note: LLM and embedding settings should already be configured 
# via initialize_llamaindex_settings() function from earlier cells

# %%
# Define file-specific metadata

doc_transactions_path = r"../table_metadata/metadata_transaction_history.txt"
doc_customer_info_path = r"../table_metadata/metadata_customer_information.txt"
doc_crs_accountreport_path = r"../table_metadata/metadata_crs_account_report.txt"
doc_crs_countrycode_path = r"../table_metadata/metadata_crs_countrycode.txt"
doc_crs_messagespec_path = r"../table_metadata/metadata_crs_messagespec.txt"

file_paths = [  doc_transactions_path, doc_customer_info_path, doc_crs_accountreport_path, doc_crs_countrycode_path, doc_crs_messagespec_path]

def get_metadata_for_files(file_paths):
    # Create a map of file path to custom metadata
    file_metadata_map = {
        
        doc_transactions_path: {
            "category": "transaction history table",
            "year": "2025-07-20",
            "department": "Finance", 
            "author": "Mzwandile Mhlongo",
            "confidentiality": "high",
            "description": "Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases"
        },
        doc_customer_info_path: {
            "category": "customer information table",
            "year": "2025-07-20",
            "department": "Finance", 
            "author": "Mzwandile Mhlongo",
            "confidentiality": "high",
            "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers"
        },
        doc_crs_accountreport_path: {
            "category": "Common Reporting Standard (CRS) Account Reporting",
            "year": "2025-07-20",
            "department": "Finance",
            "author": "Mzwandile Mhlongo",
            "confidentiality": "low",
            "description": "Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency"
        },
        doc_crs_countrycode_path: {
            "category": "Common Reporting Standard (CRS) Country Codes",
            "year": "2025-07-20",
            "department": "Finance",
            "author": "Mzwandile Mhlongo",
            "confidentiality": "low",
            "description": "Comprehensive country code reference for **Common Reporting Standard (CRS)** reporting. This table provides essential mappings between various country code formats, ensuring accurate and consistent country identification across CRS data. It is based on the **ISO 3166-1 alpha-2 standard"
        },
        doc_crs_messagespec_path: {
            "category": "Common Reporting Standard (CRS) Message Specification",
            "year": "2025-07-20",
            "department": "Finance",
            "author": "Mzwandile Mhlongo",
            "confidentiality": "low",
            "description": "This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages"
        },
    }
    
    # The function that SimpleDirectoryReader will call
    def file_metadata_func(file_path):
        # Get predefined metadata if available, otherwise return basic metadata
        if file_path in file_metadata_map:
            return file_metadata_map[file_path]
        else:
            return {
                "source": file_path,
                "file_type": os.path.splitext(file_path)[1],
                "confidentiality": "unknown"
            }
    
    return file_metadata_func


# load some documents
# documents = SimpleDirectoryReader("./data").load_data()

# Create reader with specific files and their metadata
documents = SimpleDirectoryReader(
    input_files=file_paths,
    file_metadata=get_metadata_for_files(file_paths)
).load_data()

# initialize client, setting path to save data
index_path = r"../index/chroma_db"
db = chromadb.PersistentClient(path=index_path)

# create collection
chroma_collection = db.get_or_create_collection("sql_tables_metadata")

# assign chroma as the vector_store to the context
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# create your index
index_persisted = VectorStoreIndex.from_documents(
    documents, 
    storage_context=storage_context
    
)
# Out:
# 2025-10-31 06:31:51,025 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-10-31 06:31:51,706 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-10-31 06:31:51,706 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
# create a query engine and query
my_query_engine = index_persisted.as_query_engine(
    similarity_top_k=10
)

# Create index and query engine as before
# index = VectorStoreIndex.from_documents(documents)
# query_engine = index.as_query_engine(
#     similarity_top_k=10
# )

# %%
def generate_metadata(query):
    answer = my_query_engine.query(query)
    print("\n**Query:**\n", query)
    print("\n**Answer:**\n", answer)
    print("\n**Source:**\n", answer.get_formatted_sources())
    
    # Optionally print metadata from sources to verify it's working
    print("\n**Source Metadata:**")
    for source_node in answer.source_nodes:
        print(f"- {source_node.node.metadata}")

# %%
generate_metadata("whic table contains ClosedAccount field? Return the metadata for the table that contains ClosedAccount field")
# Out:
# 2025-10-31 06:33:03,669 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-10-31 06:33:27,495 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-10-31 06:33:27,495 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# **Query:**
#  whic table contains ClosedAccount field? Return the metadata for the table that contains ClosedAccount field
#
# **Answer:**
#  Table: [DATA].[CRS_GH_AccountReport]
#
# General
# - Database: SQL Server (master)
# - Schema: dbo
# - Full Name: [DATA].[CRS_GH_AccountReport]
# - Purpose: Detailed financial account reporting data compiled for Ghana in accordance with the Common Reporting Standard (CRS). Each record represents a single reportable account within a CRS message.
#
# Keys & Relationships
# - Primary Key: (ParentID, DocRefId3) — the composite key uniquely identifies each specific account report within a given message.
# - Foreign Key: ParentID → [DATA].[CRS_GH_MessageSpec].[ParentID] (links account reports to their parent CRS message).
#
# Selected Column Definitions (highlights)
# - ParentID (varchar(255))
#   - Unique identifier linking this account report to its parent CRS message.
#   - Mandatory. Must correspond to an existing ParentID in the message spec table.
#
# - DocTypeIndic2 (varchar(255))
#   - Document type for the account-level document (OECD CRS XML).
#   - Valid values: OECD1 (New Data), OECD2 (Corrected Data), OECD3 (Void Data).
#   - Mandatory.
#
# - DocRefId3 (varchar(255))
#   - Unique reference identifier for this specific account report document within the message.
#   - Mandatory and unique per account report within a message.
#
# - AccountNumber (varchar(255))
#   - Unique identifier for the financial account (IBAN, BBAN, or proprietary).
#   - Mandatory.
#
# - AccNumberType (varchar(255))
#   - Describes format/type of AccountNumber.
#   - Valid values: IBAN, BBAN, OBAN, Other, OECD605.
#   - Mandatory.
#
# - ClosedAccount (bit)
#   - Boolean indicator whether the account was closed during the reporting period.
#   - Valid values: 0 (False), 1 (True).
#   - Mandatory.
#   - Business rule: If ClosedAccount = 1, AccountBalance must be 0.
#
# - DormantAccount (bit)
#   - Boolean indicator whether the account is considered dormant during the reporting period.
#   - Valid values: 0, 1.
#   - Mandatory.
#
# - UndocumentedAccount (bit)
#   - Boolean indicator whether the account lacks full documentation or due diligence information.
#   - Valid values: 0, 1.
#   - Mandatory.
#
# - ResCountryCode4 (nvarchar(2))
#   - ISO 3166-1 alpha-2 country code of tax residence for account holder.
#   - Mandatory. Must exist in [Ref].[CRS_CountryCode].
#
# - AcctHolderType (varchar(255))
#   - Indicates whether account holder is an individual or entity.
#   - Valid values: CRS101 (Individual), CRS102 (Entity).
#   - Mandatory.
#
# - nameType (varchar(255))
#   - Type of name provided.
#   - Valid values: OECD201 (Individual Name), OECD202 (Organization Name).
#   - Mandatory.
#
# - FirstName / LastName / MiddleName (varchar(255))
#   - FirstName and LastName: Conditional mandatory when AcctHolderType = CRS101 and nameType = OECD201; otherwise may be NULL.
#   - MiddleName: Optional for individuals.
#
# - CountryCode5 (nvarchar(2)), issuedBy7 (nvarchar(2))
#   - ISO country codes for physical address and TIN issuing authority respectively.
#   - Mandatory and must exist in [Ref].[CRS_CountryCode].
#
# - BirthDate (varchar(10))
#   - Date of birth for individual account holders; required for AcctHolderType = CRS101.
#   - Format: YYYY/MM/DD or YYYY-MM-DD.
#
# - TIN6 (varchar(255))
#   - Tax Identification Number for the account holder.
#   - Mandatory for reportable persons.
#
# - AccountBalance (decimal(18,2))
#   - Account balance as of period end.
#   - Mandatory. Must be >= 0. If ClosedAccount = 1, must be 0.
#
# - currCode (nvarchar(3))
#   - ISO 4217 currency code for AccountBalance.
#   - Mandatory.
#
# - Type (varchar(255))
#   - Type of payment/aggregated financial data (CRS501–CRS504).
#   - Mandatory.
#
# - PaymentAmnt (decimal(18,6))
#   - Amount corresponding to Type; must be >= 0.
#   - Mandatory.
#
# - currCode8 (nvarchar(3))
#   - ISO 4217 currency code for PaymentAmnt.
#   - Mandatory.
#
# - Processed (bit)
#   - Internal flag indicating whether this account report record has been processed/included in a CRS submission.
#   - Optional; defaults to 0 (False) if not set.
#
# Key Rules & Integrity Constraints
# - ParentID must reference an existing message in [DATA].[CRS_GH_MessageSpec].
# - Country code fields (ResCountryCode4, CountryCode5, issuedBy7) must be valid ISO 3166-1 alpha-2 codes present in [Ref].[CRS_CountryCode].
# - Conditional mandatory fields for individuals: when AcctHolderType = CRS101 and nameType = OECD201, FirstName, LastName, and BirthDate are required.
# - Account closure rule: if ClosedAccount = 1 then AccountBalance must equal 0.
# - Currency consistency: AccountBalance and PaymentAmnt must each have valid ISO 4217 currency codes (currCode and currCode8).
# - All enumerated fields (DocTypeIndic2, AccNumberType, AcctHolderType, nameType, Type) must adhere to the defined valid sets from OECD CRS standards.
#
# Notes
# - The composite primary key (ParentID, DocRefId3) emphasizes that AccountNumber alone may identify an account but each report instance is uniquely identified within a message by the composite key.
#
# **Source:**
#  > Source (Doc id: 483b8f2e-1e20-4bf3-86dd-361fae5a0270): Provides essential context for the structure of the `AccountNumber`.
#
# **ClosedAccount** (bit)
# - D...
#
# > Source (Doc id: ddb688fa-23e4-4178-bff4-38362583d104): <begin crs account report metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Datab...
#
# > Source (Doc id: 8ef4eeea-d004-4945-927a-76d5e18bb10a): This helps in validating and categorizing the TIN.
# - Examples: `TL`, `ME`, `AT`, `VA`, `ER`, `RO`...
#
# > Source (Doc id: af7a27cf-c02d-4a2e-bfb5-57be5fbf3a62): - **Country Code Validation**: `ResCountryCode4`, `CountryCode5`, and `issuedBy7` must all contai...
#
# > Source (Doc id: ef35f57e-28c3-4bf6-9220-e972e6b00bd6): ?####
#
# **merchant_name** (nvarchar)
# - Description: Name of merchant for purchase and payment tran...
#
# > Source (Doc id: c211ceba-0a33-44e0-978d-ecf207dda756): <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: 61e9063b-d70a-40c3-82fa-09ceae563e54): Required when `AcctHolderType` is `CRS101` and `nameType` is `OECD201`. Can be `NULL` if `AcctHol...
#
# > Source (Doc id: 67eb4107-14b2-48fc-80e8-2a8b77d9c732): <begin transaction history metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: e596ff7a-f64c-4f35-9802-24963d280f1d): The official, registered name of the reporting entity.
#
# **CountryCode** (nvarchar(2))
# - Descripti...
#
# > Source (Doc id: 6e801548-f807-46ff-b16d-74d7c38408f9): <begin crs message spec metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Databas...
#
# **Source Metadata:**
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'Common Reporting Standard (CRS) Message Specification', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages'}
# - {'category': 'Common Reporting Standard (CRS) Message Specification', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages'}

# %% [markdown]
# ## Load the index from the local vectorDB

# %%
import chromadb
import sys
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext, SimpleDirectoryReader, VectorStoreIndex #, Settings

# %%
# initialize client
index_path = r"../index/chroma_db"
db = chromadb.PersistentClient(path=index_path)

# get collection
chroma_collection = db.get_or_create_collection("sql_tables_metadata")

# assign chroma as the vector_store to the context
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# load your index from stored vectors
index = VectorStoreIndex.from_vector_store(
                                            vector_store, 
                                            storage_context=storage_context
                                        )

# create a query engine
query_engine = index.as_query_engine(similarity_top_k=10)

# %%
def generate_response(query):
    answer = query_engine.query(query)
    print("\n**Query:**\n", query)
    print("\n**Answer:**\n", answer)
    print("\n**Source:**\n", answer.get_formatted_sources())
    
    # Optionally print metadata from sources to verify it's working
    print("\n**Source Metadata:**")
    for source_node in answer.source_nodes:
        print(f"- {source_node.node.metadata}")

# %%
generate_response("which table contains ClosedAccount field? Return the metadata for the table that contains ClosedAccount field")
# Out:
# 2025-10-31 06:38:17,928 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-10-31 06:38:44,109 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-10-31 06:38:44,109 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# **Query:**
#  which table contains ClosedAccount field? Return the metadata for the table that contains ClosedAccount field
#
# **Answer:**
#  Table: [DATA].[CRS_GH_AccountReport] (SQL Server; master; schema: dbo)
#
# Primary key
# - Composite: (ParentID, DocRefId3)
#
# Foreign key
# - ParentID → [DATA].[CRS_GH_MessageSpec].[ParentID]
#
# Purpose
# - Detailed financial account reporting records (single reportable account per row) prepared for CRS reporting.
#
# Selected column metadata (types, description, examples, rules)
#
# - ParentID (varchar(255))
#   - Description: Links this account report to its parent CRS message specification.
#   - Examples: 110121c2-6227-4433-a802-54c0ed699405
#   - Rules: Mandatory; must exist in [DATA].[CRS_GH_MessageSpec].[ParentID].
#
# - DocTypeIndic2 (varchar(255))
#   - Description: Type of document for the account report (OECD CRS XML).
#   - Valid values: OECD1 (New Data), OECD2 (Corrected Data), OECD3 (Void Data)
#   - Rules: Mandatory.
#
# - DocRefId3 (varchar(255))
#   - Description: Unique reference identifier for this specific account report document.
#   - Examples: GH20231000273800732C0277B
#   - Rules: Mandatory; unique per account report within a message.
#
# - AccountNumber (varchar(255))
#   - Description: Unique identifier for the financial account (IBAN/BBAN/internal).
#   - Examples: XXX-XX-83549
#   - Rules: Mandatory.
#
# - AccNumberType (varchar(255))
#   - Description: Format/type of AccountNumber.
#   - Valid values: IBAN, BBAN, OBAN, Other, OECD605
#   - Rules: Mandatory.
#
# - ClosedAccount (bit)
#   - Description: Boolean indicator if the account was closed during the reporting period.
#   - Valid values: 0 (False), 1 (True)
#   - Examples: 0, 1
#   - Rules: Mandatory. If ClosedAccount = 1 then AccountBalance must be 0.
#
# - DormantAccount (bit)
#   - Description: Boolean indicator if the account was considered dormant during the reporting period.
#   - Valid values: 0, 1
#   - Rules: Mandatory.
#
# - UndocumentedAccount (bit)
#   - Description: Boolean indicator if the account lacks full documentation required by CRS.
#   - Valid values: 0, 1
#   - Rules: Mandatory.
#
# - ResCountryCode4 (nvarchar(2))
#   - Description: ISO 3166-1 alpha-2 country code of tax residence for the account holder.
#   - Examples: CY, LK, HN
#   - Rules: Mandatory; must exist in [Ref].[CRS_CountryCode].
#
# - AcctHolderType (varchar(255))
#   - Description: Indicates whether account holder is an individual or an entity.
#   - Valid values: CRS101 (Individual), CRS102 (Entity)
#   - Rules: Mandatory.
#
# - nameType (varchar(255))
#   - Description: Type of name provided (individual vs organisation).
#   - Valid values: OECD201 (Individual Name), OECD202 (Organization Name)
#   - Rules: Mandatory.
#
# - FirstName (varchar(255))
#   - Description: First name of individual account holder.
#   - Examples: Amanda, Adam
#   - Rules: Conditional mandatory when AcctHolderType = CRS101 and nameType = OECD201; otherwise can be NULL.
#
# - LastName (varchar(255))
#   - Description: Last/surname of individual account holder.
#   - Examples: Ibarra, Jackson
#   - Rules: Conditional mandatory when AcctHolderType = CRS101 and nameType = OECD201; otherwise can be NULL.
#
# - MiddleName (varchar(255))
#   - Description: Middle name(s) of individual account holder.
#   - Rules: Optional.
#
# - CountryCode5 (nvarchar(2))
#   - Description: ISO alpha-2 country code of the account holder's physical address.
#   - Rules: Mandatory; must exist in [Ref].[CRS_CountryCode].
#
# - Street (varchar(255))
#   - Description: Street address component.
#   - Rules: Mandatory.
#
# - PostCode (varchar(255))
#   - Description: Postal/ZIP code.
#   - Rules: Mandatory.
#
# - City (varchar(255))
#   - Description: City component of physical address.
#   - Rules: Mandatory.
#
# - BirthDate (varchar(10))
#   - Description: Date of birth (YYYY/MM/DD or YYYY-MM-DD).
#   - Examples: 1992/01/19
#   - Rules: Conditional mandatory when AcctHolderType = CRS101; otherwise can be NULL.
#
# - TIN6 (varchar(255))
#   - Description: Tax Identification Number of the account holder.
#   - Examples: XXX-XX-5272
#   - Rules: Mandatory for reportable persons.
#
# - issuedBy7 (nvarchar(2))
#   - Description: ISO alpha-2 code of the authority that issued the TIN.
#   - Rules: Mandatory; must exist in [Ref].[CRS_CountryCode].
#
# - AccountBalance (decimal(18,2))
#   - Description: Total balance as of end of reporting period.
#   - Examples: 5731.88
#   - Rules: Mandatory; >= 0. If ClosedAccount = 1 then must be 0.
#
# - currCode (nvarchar(3))
#   - Description: ISO 4217 currency code for AccountBalance.
#   - Examples: EUR, USD, GHS
#   - Rules: Mandatory.
#
# - Type (varchar(255))
#   - Description: Type of payment/aggregated financial data.
#   - Valid values: CRS501, CRS502, CRS503, CRS504
#   - Rules: Mandatory.
#
# - PaymentAmnt (decimal(18,6))
#   - Description: Amount for the specified Type.
#   - Examples: 0.192482
#   - Rules: Mandatory; >= 0.
#
# - currCode8 (nvarchar(3))
#   - Description: ISO 4217 currency code for PaymentAmnt.
#   - Rules: Mandatory.
#
# - Processed (bit)
#   - Description: Internal flag indicating if this record has been processed/included in a CRS submission.
#   - Valid values: 0, 1
#   - Rules: Optional; defaults to 0 if not set.
#
# Key relationships & integrity rules (summary)
# - Parent-child: ParentID must reference an existing message record.
# - Country code validation: ResCountryCode4, CountryCode5, issuedBy7 must be valid ISO alpha-2 codes present in [Ref].[CRS_CountryCode].
# - Conditional mandatory fields: FirstName, LastName, BirthDate required when AcctHolderType = CRS101 and nameType = OECD201.
# - Account closure vs balance: If ClosedAccount = 1 then AccountBalance must equal 0.
# - Currency consistency: AccountBalance and PaymentAmnt must have valid ISO 4217 currency codes in currCode and currCode8.
# - Value sets: DocTypeIndic2, AccNumberType, AcctHolderType, nameType, Type must adhere to the defined valid sets.
#
# **Source:**
#  > Source (Doc id: 483b8f2e-1e20-4bf3-86dd-361fae5a0270): Provides essential context for the structure of the `AccountNumber`.
#
# **ClosedAccount** (bit)
# - D...
#
# > Source (Doc id: ddb688fa-23e4-4178-bff4-38362583d104): <begin crs account report metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Datab...
#
# > Source (Doc id: 8ef4eeea-d004-4945-927a-76d5e18bb10a): This helps in validating and categorizing the TIN.
# - Examples: `TL`, `ME`, `AT`, `VA`, `ER`, `RO`...
#
# > Source (Doc id: af7a27cf-c02d-4a2e-bfb5-57be5fbf3a62): - **Country Code Validation**: `ResCountryCode4`, `CountryCode5`, and `issuedBy7` must all contai...
#
# > Source (Doc id: ef35f57e-28c3-4bf6-9220-e972e6b00bd6): ?####
#
# **merchant_name** (nvarchar)
# - Description: Name of merchant for purchase and payment tran...
#
# > Source (Doc id: c211ceba-0a33-44e0-978d-ecf207dda756): <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: 61e9063b-d70a-40c3-82fa-09ceae563e54): Required when `AcctHolderType` is `CRS101` and `nameType` is `OECD201`. Can be `NULL` if `AcctHol...
#
# > Source (Doc id: 67eb4107-14b2-48fc-80e8-2a8b77d9c732): <begin transaction history metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: e596ff7a-f64c-4f35-9802-24963d280f1d): The official, registered name of the reporting entity.
#
# **CountryCode** (nvarchar(2))
# - Descripti...
#
# > Source (Doc id: 6e801548-f807-46ff-b16d-74d7c38408f9): <begin crs message spec metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Databas...
#
# **Source Metadata:**
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'Common Reporting Standard (CRS) Message Specification', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages'}
# - {'category': 'Common Reporting Standard (CRS) Message Specification', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages'}

# %%
generate_response("generate the full table details without intepreting or editing anything: customer information full table details")
# Out:
# 2025-10-31 06:38:44,720 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-10-31 06:39:28,652 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-10-31 06:39:28,652 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# **Query:**
#  generate the full table details without intepreting or editing anything: customer information full table details
#
# **Answer:**
#  Database: SQL Server (master)
# Schema: dbo
# Table: customer_information
# Description: Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
# Primary Key: id
# Full Name: [dbo].[customer_information]
#
# Columns:
#
# - id (int)
#   - Description: Unique customer identifier, 8-digit number
#   - Range: 10000000 to 99999999
#   - Examples: 10474206, 10962741, 13765547
#   - Rules: Auto-generated unique identifier for each customer
#
# - full_name (nvarchar)
#   - Description: Customer's complete name (first and last name)
#   - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
#   - Rules: Required field, contains customer's legal name
#
# - email (nvarchar)
#   - Description: Customer's email address for communication
#   - Examples: nelsoneddie@example.net, dillonjodi@example.net
#   - Rules: Must be valid email format, used for notifications
#
# - phone_number (nvarchar)
#   - Description: Customer's contact phone number
#   - Examples: +1-555-123-4567, (555) 987-6543
#   - Rules: Various formats accepted, primary contact method
#
# - address (nvarchar)
#   - Description: Customer's physical address (street, city, state, zip)
#   - Examples: 123 Main St, Anytown, ST 12345
#   - Rules: Complete postal address for correspondence
#
# - account_number (nvarchar)
#   - Description: Bank account number associated with the customer
#   - Examples: 1234567890, 9876543210
#   - Rules: 10-digit unique account identifier
#
# - account_type (nvarchar)
#   - Description: Type of bank account held by the customer
#   - Valid Values: Savings, Cheque, Business
#   - Examples: Savings, Cheque, Business
#   - Rules: Determines account features and limitations
#
# - balance (decimal)
#   - Description: Current account balance in local currency
#   - Range: 100.00 to 50000.00
#   - Examples: 8383.72, 19437.26, 45030.79
#   - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# - gender (nvarchar)
#   - Description: Customer's gender identification
#   - Valid Values: Male, Female
#   - Examples: Male, Female
#   - Rules: Used for demographic analysis and targeted marketing
#
# - age (int)
#   - Description: Customer's age in years
#   - Range: 18 to 75
#   - Examples: 61, 30, 64
#   - Rules: Must be 18+ to open account, affects product eligibility
#
# - occupation (nvarchar)
#   - Description: Customer's current job title or profession
#   - Examples: English as a second language teacher, Engineering geologist, Information systems manager
#   - Rules: Used for risk assessment and income verification
#
# - income (decimal)
#   - Description: Customer's annual income in local currency
#   - Range: 20000.00 to 150000.00
#   - Examples: 45000.0, 32000.0, 85000.0
#   - Rules: Used for loan eligibility and credit limit determination
#
# - income_source (nvarchar)
#   - Description: Primary source of customer's income
#   - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
#   - Examples: Employment, Self-employment, Business
#   - Rules: Affects income stability assessment for lending
#
# - income_category (nvarchar)
#   - Description: Income classification based on amount
#   - Valid Values: Low, Medium, High
#   - Examples: Low, Medium, High
#   - Rules: Determines product offerings and credit limits
#
# - previous_loans_count (int)
#   - Description: Number of previous loans taken by the customer
#   - Range: 0 to 5
#   - Examples: 0, 2, 5
#   - Rules: Higher count may affect future loan approval
#
# - credit_score (int)
#   - Description: Customer's credit score based on credit history
#   - Range: 300 to 850
#   - Examples: 718, 807, 511
#   - Rules: Primary factor in loan approval and interest rate determination
#
# - loan_eligible (bit)
#   - Description: Boolean indicating if customer is eligible for loans
#   - Valid Values: 0, 1
#   - Examples: 1, 0
#   - Rules: Determines access to lending products
#
# - eligible_loan_amount (decimal)
#   - Description: Maximum loan amount customer is eligible for
#   - Examples: 25000.0, 50000.0, 100000.0
#   - Rules: Sets upper limit for loan applications
#
# - loan_amount_applied_for (decimal)
#   - Description: Amount of loan currently applied for or received
#   - Examples: 15000.0, 30000.0, 0.0
#   - Rules: Cannot exceed eligible_loan_amount, 0 if no loan application
#
# - loan_status (nvarchar)
#   - Description: Current status of loan application or existing loan
#   - Valid Values: Pending, Approved, Active, Closed, None
#   - Examples: Active, Pending, Approved
#   - Rules: NULL if no loan application
#
# - loan_tenure (int)
#   - Description: Loan repayment period in months
#   - Range: 6 to 60 months
#   - Examples: 12, 24, 60
#   - Rules: Longer tenure increases interest rate, NULL if no loan
#
# - loan_interest_rate (decimal)
#   - Description: Annual interest rate for the loan as a percentage
#   - Range: 3.50% to 20.00%
#   - Examples: 7.5, 12.25, 15.0
#   - Rules: NULL if no loan, calculated using risk-based pricing
#
# - loan_purpose (nvarchar)
#   - Description: Reason for taking the loan
#   - Valid Values: Home, Education, Vehicle, Personal, Business
#   - Examples: Home, Education, Vehicle
#   - Rules: Required for loan applications, affects interest rates
#
# - loan_application_date (datetime)
#   - Description: Date when loan application was submitted
#   - Examples: 2023-05-15 10:30:00, 2024-01-20 14:45:00
#   - Rules: NULL if no loan application, within last 2 years
#
# - last_login (datetime)
#   - Description: Last time customer accessed online banking
#   - Examples: 2025-06-08 09:15:00, 2025-06-07 18:30:00
#   - Rules: Used to track customer engagement and activity
#
# - product_holding (nvarchar)
#   - Description: JSON array of bank products held by the customer
#   - Examples: ["Checking Account", "Overdraft Protection", "Foreign Currency Exchange"], ["Investment Advisory Services"], ["Home Mortgages", "Insurance Products", "Savings Account"]
#   - Rules: Determines cross-selling opportunities and customer value
#
# - no_product_holding (int)
#   - Description: Count of products currently held by the customer
#   - Range: 1 to 15
#   - Examples: 3, 1, 9
#   - Rules: Higher count indicates deeper customer relationship
#
# - entrenchment_score (decimal)
#   - Description: Percentage of total available products held by customer
#   - Range: 0.00% to 100.00%
#   - Examples: 13.04, 4.35, 39.13
#   - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# Key Relationships & Rules:
#
# - loan_eligible is calculated from credit_score: loan_eligible = 1 if credit_score >= 580, else 0
# - income_category is calculated from income: Low: <30K, Medium: 30K-70K, High: >70K
# - no_product_holding is calculated from product_holding: COUNT of JSON array items
# - entrenchment_score is calculated from no_product_holding: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# **Source:**
#  > Source (Doc id: c211ceba-0a33-44e0-978d-ecf207dda756): <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: 2a08abe7-d510-45e6-9819-7e7de267db36): 00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer r...
#
# > Source (Doc id: 67eb4107-14b2-48fc-80e8-2a8b77d9c732): <begin transaction history metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Data...
#
# > Source (Doc id: ef35f57e-28c3-4bf6-9220-e972e6b00bd6): ?####
#
# **merchant_name** (nvarchar)
# - Description: Name of merchant for purchase and payment tran...
#
# > Source (Doc id: c2c418a4-e65a-4450-a608-49a62b6fafbc): Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limit...
#
# > Source (Doc id: af7a27cf-c02d-4a2e-bfb5-57be5fbf3a62): - **Country Code Validation**: `ResCountryCode4`, `CountryCode5`, and `issuedBy7` must all contai...
#
# > Source (Doc id: ddb688fa-23e4-4178-bff4-38362583d104): <begin crs account report metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Datab...
#
# > Source (Doc id: 483b8f2e-1e20-4bf3-86dd-361fae5a0270): Provides essential context for the structure of the `AccountNumber`.
#
# **ClosedAccount** (bit)
# - D...
#
# > Source (Doc id: a1bfe6ac-244d-4f59-ac82-a70a78db6e0f): - Examples: `MSGREFID-2024-GH-001`, `MSGREFID-ABC-2024-002`
# - Rules: **Mandatory**. Must be uniqu...
#
# > Source (Doc id: 61e9063b-d70a-40c3-82fa-09ceae563e54): Required when `AcctHolderType` is `CRS101` and `nameType` is `OECD201`. Can be `NULL` if `AcctHol...
#
# **Source Metadata:**
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# - {'category': 'customer information table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}
# - {'category': 'Common Reporting Standard (CRS) Message Specification', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'This table stores the crucial **header and reporting entity information** for **Common Reporting Standard (CRS) messages'}
# - {'category': 'Common Reporting Standard (CRS) Account Reporting', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'low', 'description': 'Detailed financial account reporting data in accordance with **Common Reporting Standard (CRS)** requirements. This table captures comprehensive information about account holders and their financial accounts, crucial for international tax transparency'}

# %%
import json
import logging
import re
import json

import os
from dotenv import load_dotenv, find_dotenv
import warnings
warnings.filterwarnings("ignore")
load_dotenv(find_dotenv())

import chromadb
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI as LlamaIndexOpenAI

# OpenAI Configuration
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
OPENAI_MODEL = os.environ.get("OPENAI_MODEL", "gpt-4o")
OPENAI_EMBEDDING_MODEL = os.environ.get("OPENAI_EMBEDDING_MODEL", "text-embedding-3-small")

# Set up LLM with standard OpenAI
llm = LlamaIndexOpenAI(
    api_key=OPENAI_API_KEY,
    model=OPENAI_MODEL,
)

# Set up embedding model with standard OpenAI
embedding_model = OpenAIEmbedding(
    model=OPENAI_EMBEDDING_MODEL,
    api_key=OPENAI_API_KEY,
    api_base="https://api.openai.com/v1",
)

Settings.llm = llm
Settings.embed_model = embedding_model

# Initialize ChromaDB client
index_path = r"C:\Users\A238737\OneDrive - Standard Bank\Documents\GroupFunctions\rag-systems\ai-analyst-demo\text_sql_analysis\index\chroma_db"
db = chromadb.PersistentClient(path=index_path)

# Get collection
chroma_collection = db.get_or_create_collection("sql_tables_metadata")
print(f"Chroma collection '{chroma_collection.name}' loaded successfully.")

# Assign chroma as the vector_store to the context
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# Load your index from stored vectors
index = VectorStoreIndex.from_vector_store(
    vector_store, storage_context=storage_context
)

# Create a query engine
query_engine = index.as_query_engine(similarity_top_k=10)

def agent_table_rag(query):
    return query_engine.query("retrieve the full tables metadata without intepreting or editing anything for the following given tables: " + query)

def check_and_display_collection_info(client_db, collection_name_to_check):
    """
    Checks if a ChromaDB collection exists and displays its content if it does.
    Also lists all available collections.
    """
    print("\n--- ChromaDB Collection Information ---")

    # 1. List all collections
    print("Listing all collections:")
    all_collections = client_db.list_collections()
    if all_collections:
        for col in all_collections:
            print(f"- {col.name}")
    else:
        print("No collections found in the database.")

    # 2. Check if the specified collection exists
    print(f"\nChecking if collection '{collection_name_to_check}' exists...")
    try:
        target_collection = client_db.get_collection(collection_name_to_check)
        print(f"Collection '{collection_name_to_check}' exists!")

        # 3. Get and display some content from the index
        print(f"\nDisplaying first 5 items from '{collection_name_to_check}':")
        collection_content = target_collection.peek(limit=5)

        if collection_content and collection_content.get('documents'):
            for i, doc in enumerate(collection_content['documents']):
                print(f"--- Item {i+1} ---")
                print(f"ID: {collection_content['ids'][i]}")
                print(f"Document: {doc}")
                if collection_content.get('metadatas') and collection_content['metadatas'][i]:
                    print(f"Metadata: {json.dumps(collection_content['metadatas'][i], indent=2)}")
                print("-" * 20)
        else:
            print(f"Collection '{collection_name_to_check}' is empty or has no documents.")

    except chromadb.exceptions.CollectionNotFoundError:
        print(f"Collection '{collection_name_to_check}' does NOT exist.")
    except Exception as e:
        print(f"An error occurred while accessing collection '{collection_name_to_check}': {e}")
    print("-------------------------------------")


if __name__ == "__main__":
    # Call the new function to check and display collection info
    check_and_display_collection_info(db, "sql_tables_metadata")

    user_request = "customer information"
    try:
        print("\nRetrieving relevant tables for the request:", user_request)
        table_results = query_engine.query("retrieve the full tables metadata without intepreting or editing anything for the following given tables: " + user_request)
        print("Type of result:", type(table_results))
        print("Raw result:", repr(table_results))
        if not table_results:
            print("No results returned from query.")
        else:
            # If it's not a string, print its attributes
            if not isinstance(table_results, str):
                print("Result attributes:", dir(table_results))
                # Try to print a 'response' or 'text' attribute if present
                if hasattr(table_results, 'response'):
                    print("Response attribute:", table_results.response)
                if hasattr(table_results, 'text'):
                    print("Text attribute:", table_results.text)
            print("Relevant tables retrieved successfully!")
            print(table_results)
    except Exception as e:
        print(f"Error retrieving tables: {e}")
# Out:
# Chroma collection 'sql_tables_metadata' loaded successfully.
#
# --- ChromaDB Collection Information ---
# Listing all collections:
# - sql_tables_metadata
#
# Checking if collection 'sql_tables_metadata' exists...
# Collection 'sql_tables_metadata' exists!
#
# Displaying first 5 items from 'sql_tables_metadata':
# --- Item 1 ---
# ID: 7d83553b-a671-4803-964f-03d3545900d2
# Document: <begin transaction history metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Server**: localhost\SQLEXPRESS
# - **Schema**: dbo
#
# ## Table: transaction_history
# Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases
#
# ### Table Structure
# **Full Name**: [dbo].[transaction_history]
# **Records**: 5000+ transactions
# **Primary Key**: transaction_id
# **Foreign Keys**: customer_id
# **Time Range**: Last 2 years of transaction data
#
# ### Column Definitions
#
# **transaction_id** (bigint)
# - Description: Unique transaction identifier, 12-digit number
# - Range: 100000000000 to 999999999999
# - Examples: 679551814302, 376513881618, 994709101726
# - Rules: Auto-generated unique identifier for each transaction
#
# **customer_id** (int)
# - Description: Customer identifier linking to customer_information table
# - Range: 10000000 to 99999999
# - Examples: 10000001, 10000002, 10000003
# - Rules: Must exist in customer_information table
#
# **transaction_date** (datetime)
# - Description: Date and time when the transaction occurred
# - Examples: 2023-06-15 14:30:22, 2024-11-28 09:15:45, 2025-01-12 16:45:33
# - Rules: Cannot be future date, used for transaction ordering and reporting
#
# **transaction_type** (nvarchar)
# - Description: Type of transaction performed
# - Valid Values: Deposit, Withdrawal, Transfer, Payment, Purchase, Refund, Fee, Interest, Loan Payment, Salary
# - Examples: Deposit, Withdrawal, Transfer
# - Rules: Determines transaction processing rules and account impact
#
# **amount** (decimal)
# - Description: Transaction amount in specified currency (negative for debits, positive for credits)
# - Range: -100000.00 to 100000.00
# - Examples: 1500.5, -89.99, 25000.0
# - Rules: Negative values represent debits (withdrawals, payments, fees), positive values represent credits (deposits, refunds, interest)
#
# **currency** (nvarchar)
# - Description: ISO 4217 currency code for the transaction
# - Valid Values: ZAR, USD, EUR, GBP, JPY
# - Examples: ZAR, USD, EUR
# - Rules: Primarily ZAR (85%), with some international currencies for forex transactions
#
# **description** (nvarchar)
# - Description: Human-readable description of the transaction
# - Examples: Groceries purchase at Woolworths, Transfer to John Smith, Salary payment from ABC Corp
# - Rules: Auto-generated based on transaction type and context
#
# **category** (nvarchar)
# - Description: Transaction category for spending analysis
# - Valid Values: Groceries, Gas, Restaurant, Shopping, Utilities, Healthcare, Entertainment, Travel, Education, Insurance, Banking, Investment, Salary, Bonus, Refund, Other
# - Examples: Groceries, Gas, Restaurant
# - Rules: Used for budgeting and spending pattern analysis
#
# **channel** (nvarchar)
# - Description: Channel through which the transaction was made
# - Valid Values: ATM, Online Banking, Mobile App, Branch, POS Terminal, Wire Transfer, ACH, Check, Direct Deposit
# - Examples: ATM, Online Banking, Mobile App
# - Rules: Tracks customer behavior and channel preference
#
# **status** (nvarchar)
# - Description: Current status of the transaction
# - Valid Values: Completed, Pending, Failed, Cancelled
# - Examples: Completed, Pending, Failed
# - Rules: Only Completed transactions affect account balance
#
# **reference_number** (nvarchar)
# - Description: Unique reference number for transaction tracking
# - Examples: REF1234AB5678, REF9876XY1234
# - Rules: Used for transaction inquiries and dispute resolution
# - Pattern: REF####?
# Metadata: {
#   "ref_doc_id": "1d392d91-51fb-46a1-bd86-d98bcc79a0a5",
#   "department": "Finance",
#   "confidentiality": "high",
#   "_node_type": "TextNode",
#   "category": "transaction history table",
#   "_node_content": "{\"id_\": \"7d83553b-a671-4803-964f-03d3545900d2\", \"embedding\": null, \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"1d392d91-51fb-46a1-bd86-d98bcc79a0a5\", \"node_type\": \"4\", \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"hash\": \"ed4701490b48486ed69fd0859fe4fcd7195fb9c13f2d6561753ac54cbcb3a80b\", \"class_name\": \"RelatedNodeInfo\"}, \"3\": {\"node_id\": \"d5d0496f-3f94-4d5f-9be5-adc6df279cf9\", \"node_type\": \"1\", \"metadata\": {}, \"hash\": \"e515675f5abadcd730421462487e6a6f673f0fea415b76ae87b9dde9bb85f4ee\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 0, \"end_char_idx\": 3592, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "year": "2025-07-20",
#   "doc_id": "1d392d91-51fb-46a1-bd86-d98bcc79a0a5",
#   "description": "Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases",
#   "author": "Mzwandile Mhlongo",
#   "document_id": "1d392d91-51fb-46a1-bd86-d98bcc79a0a5"
# }
# --------------------
# --- Item 2 ---
# ID: d5d0496f-3f94-4d5f-9be5-adc6df279cf9
# Document: ?####
#
# **merchant_name** (nvarchar)
# - Description: Name of merchant for purchase and payment transactions
# - Examples: Woolworths, Shell Garage, Amazon
# - Rules: Only populated for Purchase and Payment transaction types
#
# **merchant_category** (nvarchar)
# - Description: Category of merchant for purchase and payment transactions
# - Examples: Groceries, Gas, Shopping
# - Rules: Matches category field for Purchase and Payment transactions
#
# **account_from** (nvarchar)
# - Description: Source account number for the transaction
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit account number, links to customer's account
#
# **account_to** (nvarchar)
# - Description: Destination account number for transfer transactions
# - Examples: 5555666677, 1111222233
# - Rules: Only populated for Transfer transaction types
#
# **balance_after** (decimal)
# - Description: Account balance after the transaction was processed
# - Range: 0.00 to 100000.00
# - Examples: 15420.5, 8750.25, 45000.0
# - Rules: Snapshot of balance immediately after transaction completion
#
# **location** (nvarchar)
# - Description: Geographic location where the transaction occurred
# - Examples: Johannesburg, South Africa, Cape Town, South Africa, London, United Kingdom
# - Rules: Used for fraud detection and geographic spending analysis
#
# **created_at** (datetime)
# - Description: Timestamp when the transaction record was created in the system
# - Examples: 2025-06-09 10:30:22, 2025-06-09 11:15:45
# - Rules: System audit field, automatically populated
#
# **updated_at** (datetime)
# - Description: Timestamp when the transaction record was last updated
# - Examples: 2025-06-09 10:30:22, 2025-06-09 11:15:45
# - Rules: System audit field, automatically updated on changes
#
# ### Key Relationships & Rules
#
# - **customer_id** references **customer_information.id**: Each transaction belongs to one customer, customers can have many transactions
# - **merchant_name** depends on **transaction_type**: merchant_name is only populated when transaction_type is 'Purchase' or 'Payment'
# - **account_to** depends on **transaction_type**: account_to is only populated when transaction_type is 'Transfer'
# - **Amount Sign Convention**: Negative amounts for debits (Withdrawal, Payment, Purchase, Fee, Loan Payment), positive for credits (Deposit, Salary, Interest, Refund)
# - **Status Constraint**: balance_after only reflects completed transactions, not pending/failed ones
#
# </end transaction history metadata>
# Metadata: {
#   "ref_doc_id": "1d392d91-51fb-46a1-bd86-d98bcc79a0a5",
#   "document_id": "1d392d91-51fb-46a1-bd86-d98bcc79a0a5",
#   "department": "Finance",
#   "description": "Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases",
#   "doc_id": "1d392d91-51fb-46a1-bd86-d98bcc79a0a5",
#   "confidentiality": "high",
#   "_node_type": "TextNode",
#   "year": "2025-07-20",
#   "_node_content": "{\"id_\": \"d5d0496f-3f94-4d5f-9be5-adc6df279cf9\", \"embedding\": null, \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"1d392d91-51fb-46a1-bd86-d98bcc79a0a5\", \"node_type\": \"4\", \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"hash\": \"ed4701490b48486ed69fd0859fe4fcd7195fb9c13f2d6561753ac54cbcb3a80b\", \"class_name\": \"RelatedNodeInfo\"}, \"2\": {\"node_id\": \"7d83553b-a671-4803-964f-03d3545900d2\", \"node_type\": \"1\", \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"hash\": \"f092181a5af30d1ab1231e9128a7dfa01fd8ee517fc7ba5bf6e521042b6c7a3d\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 3592, \"end_char_idx\": 6067, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "author": "Mzwandile Mhlongo",
#   "category": "transaction history table"
# }
# --------------------
# --- Item 3 ---
# ID: df17ad6f-6ce0-4006-8d48-993e3ac94343
# Document: <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Schema**: dbo
#
# ## Table: customer_information
# Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
#
# ### Table Structure
# **Full Name**: [dbo].[customer_information]
# **Primary Key**: id
#
# ### Column Definitions
#
# **id** (int)
# - Description: Unique customer identifier, 8-digit number
# - Range: 10000000 to 99999999
# - Examples: 10474206, 10962741, 13765547
# - Rules: Auto-generated unique identifier for each customer
#
# **full_name** (nvarchar)
# - Description: Customer's complete name (first and last name)
# - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
# - Rules: Required field, contains customer's legal name
#
# **email** (nvarchar)
# - Description: Customer's email address for communication
# - Examples: nelsoneddie@example.net, dillonjodi@example.net
# - Rules: Must be valid email format, used for notifications
#
# **phone_number** (nvarchar)
# - Description: Customer's contact phone number
# - Examples: +1-555-123-4567, (555) 987-6543
# - Rules: Various formats accepted, primary contact method
#
# **address** (nvarchar)
# - Description: Customer's physical address (street, city, state, zip)
# - Examples: 123 Main St, Anytown, ST 12345
# - Rules: Complete postal address for correspondence
#
# **account_number** (nvarchar)
# - Description: Bank account number associated with the customer
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit unique account identifier
#
# **account_type** (nvarchar)
# - Description: Type of bank account held by the customer
# - Valid Values: Savings, Cheque, Business
# - Examples: Savings, Cheque, Business
# - Rules: Determines account features and limitations
#
# **balance** (decimal)
# - Description: Current account balance in local currency
# - Range: 100.00 to 50000.00
# - Examples: 8383.72, 19437.26, 45030.79
# - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# **gender** (nvarchar)
# - Description: Customer's gender identification
# - Valid Values: Male, Female
# - Examples: Male, Female
# - Rules: Used for demographic analysis and targeted marketing
#
# **age** (int)
# - Description: Customer's age in years
# - Range: 18 to 75
# - Examples: 61, 30, 64
# - Rules: Must be 18+ to open account, affects product eligibility
#
# **occupation** (nvarchar)
# - Description: Customer's current job title or profession
# - Examples: English as a second language teacher, Engineering geologist, Information systems manager
# - Rules: Used for risk assessment and income verification
#
# **income** (decimal)
# - Description: Customer's annual income in local currency
# - Range: 20000.00 to 150000.00
# - Examples: 45000.0, 32000.0, 85000.0
# - Rules: Used for loan eligibility and credit limit determination
#
# **income_source** (nvarchar)
# - Description: Primary source of customer's income
# - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
# - Examples: Employment, Self-employment, Business
# - Rules: Affects income stability assessment for lending
#
# **income_category** (nvarchar)
# - Description: Income classification based on amount
# - Valid Values: Low, Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1,
# Metadata: {
#   "ref_doc_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "year": "2025-07-20",
#   "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers",
#   "_node_content": "{\"id_\": \"df17ad6f-6ce0-4006-8d48-993e3ac94343\", \"embedding\": null, \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"f7554772-6f74-4866-bdcc-2819cdf7bc17\", \"node_type\": \"4\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"dda5eb6f7dcc5abd58eafb75713640da6e17d9a6406ad9bd87939bd68869aa12\", \"class_name\": \"RelatedNodeInfo\"}, \"3\": {\"node_id\": \"dd7c3234-06d7-4e38-a302-40755a2ded48\", \"node_type\": \"1\", \"metadata\": {}, \"hash\": \"f26ab155d073ac962fabe9dfed35b32cd291c161325eaef1f2b3540b5262e2bc\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 2, \"end_char_idx\": 3955, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "category": "customer information table",
#   "confidentiality": "high",
#   "_node_type": "TextNode",
#   "doc_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "author": "Mzwandile Mhlongo",
#   "document_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "department": "Finance"
# }
# --------------------
# --- Item 4 ---
# ID: dd7c3234-06d7-4e38-a302-40755a2ded48
# Document: Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1, 0
# - Rules: Determines access to lending products
#
# **eligible_loan_amount** (decimal)
# - Description: Maximum loan amount customer is eligible for
# - Examples: 25000.0, 50000.0, 100000.0
# - Rules: Sets upper limit for loan applications
#
# **loan_amount_applied_for** (decimal)
# - Description: Amount of loan currently applied for or received
# - Examples: 15000.0, 30000.0, 0.0
# - Rules: Cannot exceed eligible_loan_amount, 0 if no loan application
#
# **loan_status** (nvarchar)
# - Description: Current status of loan application or existing loan
# - Valid Values: Pending, Approved, Active, Closed, None
# - Examples: Active, Pending, Approved
# - Rules: NULL if no loan application
#
# **loan_tenure** (int)
# - Description: Loan repayment period in months
# - Range: 6 to 60 months
# - Examples: 12, 24, 60
# - Rules: Longer tenure increases interest rate, NULL if no loan
#
# **loan_interest_rate** (decimal)
# - Description: Annual interest rate for the loan as a percentage
# - Range: 3.50% to 20.00%
# - Examples: 7.5, 12.25, 15.0
# - Rules: NULL if no loan, calculated using risk-based pricing
#
# **loan_purpose** (nvarchar)
# - Description: Reason for taking the loan
# - Valid Values: Home, Education, Vehicle, Personal, Business
# - Examples: Home, Education, Vehicle
# - Rules: Required for loan applications, affects interest rates
#
# **loan_application_date** (datetime)
# - Description: Date when loan application was submitted
# - Examples: 2023-05-15 10:30:00, 2024-01-20 14:45:00
# - Rules: NULL if no loan application, within last 2 years
#
# **last_login** (datetime)
# - Description: Last time customer accessed online banking
# - Examples: 2025-06-08 09:15:00, 2025-06-07 18:30:00
# - Rules: Used to track customer engagement and activity
#
# **product_holding** (nvarchar)
# - Description: JSON array of bank products held by the customer
# - Examples: ["Checking Account", "Overdraft Protection", "Foreign Currency Exchange"], ["Investment Advisory Services"], ["Home Mortgages", "Insurance Products", "Savings Account"]
# - Rules: Determines cross-selling opportunities and customer value
#
# **no_product_holding** (int)
# - Description: Count of products currently held by the customer
# - Range: 1 to 15
# - Examples: 3, 1, 9
# - Rules: Higher count indicates deeper customer relationship
#
# **entrenchment_score** (decimal)
# - Description: Percentage of total available products held by customer
# - Range: 0.00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score,
# Metadata: {
#   "_node_content": "{\"id_\": \"dd7c3234-06d7-4e38-a302-40755a2ded48\", \"embedding\": null, \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"f7554772-6f74-4866-bdcc-2819cdf7bc17\", \"node_type\": \"4\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"dda5eb6f7dcc5abd58eafb75713640da6e17d9a6406ad9bd87939bd68869aa12\", \"class_name\": \"RelatedNodeInfo\"}, \"2\": {\"node_id\": \"df17ad6f-6ce0-4006-8d48-993e3ac94343\", \"node_type\": \"1\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"a1ad7bc4bf9ce28e24f546d53c0befa82d04f4aa2135430b4a86105391181c42\", \"class_name\": \"RelatedNodeInfo\"}, \"3\": {\"node_id\": \"8fcb6eae-f245-4c22-9207-5343db7366ce\", \"node_type\": \"1\", \"metadata\": {}, \"hash\": \"909dd97a752f6ee33d1c9d12fd157f3b699fcf0d72895c4b0eacf1504f273e1a\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 3319, \"end_char_idx\": 7051, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers",
#   "department": "Finance",
#   "doc_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "document_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "ref_doc_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "_node_type": "TextNode",
#   "author": "Mzwandile Mhlongo",
#   "confidentiality": "high",
#   "year": "2025-07-20",
#   "category": "customer information table"
# }
# --------------------
# --- Item 5 ---
# ID: 8fcb6eae-f245-4c22-9207-5343db7366ce
# Document: 00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# </end customer information metadata>
# Metadata: {
#   "author": "Mzwandile Mhlongo",
#   "year": "2025-07-20",
#   "confidentiality": "high",
#   "doc_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "department": "Finance",
#   "ref_doc_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers",
#   "_node_type": "TextNode",
#   "document_id": "f7554772-6f74-4866-bdcc-2819cdf7bc17",
#   "_node_content": "{\"id_\": \"8fcb6eae-f245-4c22-9207-5343db7366ce\", \"embedding\": null, \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"f7554772-6f74-4866-bdcc-2819cdf7bc17\", \"node_type\": \"4\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"dda5eb6f7dcc5abd58eafb75713640da6e17d9a6406ad9bd87939bd68869aa12\", \"class_name\": \"RelatedNodeInfo\"}, \"2\": {\"node_id\": \"dd7c3234-06d7-4e38-a302-40755a2ded48\", \"node_type\": \"1\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"e1b42aa09ee1b83a06ff13ff0bad1f2b0a013b7f5be7adf9c990baf0a6e1feed\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 6361, \"end_char_idx\": 7116, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "category": "customer information table"
# }
# --------------------
# -------------------------------------
#
# Retrieving relevant tables for the request: customer information
# Type of result: <class 'llama_index.core.base.response.schema.Response'>
# Raw result: Response(response='<begin customer information metadata>\n# Database Schema Information\n\n## Database Details\n- **Database**: SQL Server (master)\n- **Schema**: dbo\n\n## Table: customer_information\nComprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers\n\n### Table Structure\n**Full Name**: [dbo].[customer_information]\n**Primary Key**: id\n\n### Column Definitions\n\n**id** (int)\n- Description: Unique customer identifier, 8-digit number\n- Range: 10000000 to 99999999\n- Examples: 10474206, 10962741, 13765547\n- Rules: Auto-generated unique identifier for each customer\n\n**full_name** (nvarchar)\n- Description: Customer\'s complete name (first and last name)\n- Examples: Rachel Benitez, Samuel Anderson, Austin Perkins\n- Rules: Required field, contains customer\'s legal name\n\n**email** (nvarchar)\n- Description: Customer\'s email address for communication\n- Examples: nelsoneddie@example.net, dillonjodi@example.net\n- Rules: Must be valid email format, used for notifications\n\n**phone_number** (nvarchar)\n- Description: Customer\'s contact phone number\n- Examples: +1-555-123-4567, (555) 987-6543\n- Rules: Various formats accepted, primary contact method\n\n**address** (nvarchar)\n- Description: Customer\'s physical address (street, city, state, zip)\n- Examples: 123 Main St, Anytown, ST 12345\n- Rules: Complete postal address for correspondence\n\n**account_number** (nvarchar)\n- Description: Bank account number associated with the customer\n- Examples: 1234567890, 9876543210\n- Rules: 10-digit unique account identifier\n\n**account_type** (nvarchar)\n- Description: Type of bank account held by the customer\n- Valid Values: Savings, Cheque, Business\n- Examples: Savings, Cheque, Business\n- Rules: Determines account features and limitations\n\n**balance** (decimal)\n- Description: Current account balance in local currency\n- Range: 100.00 to 50000.00\n- Examples: 8383.72, 19437.26, 45030.79\n- Rules: Updated in real-time with transactions, minimum balance varies by account type\n\n**gender** (nvarchar)\n- Description: Customer\'s gender identification\n- Valid Values: Male, Female\n- Examples: Male, Female\n- Rules: Used for demographic analysis and targeted marketing\n\n**age** (int)\n- Description: Customer\'s age in years\n- Range: 18 to 75\n- Examples: 61, 30, 64\n- Rules: Must be 18+ to open account, affects product eligibility\n\n**occupation** (nvarchar)\n- Description: Customer\'s current job title or profession\n- Examples: English as a second language teacher, Engineering geologist, Information systems manager\n- Rules: Used for risk assessment and income verification\n\n**income** (decimal)\n- Description: Customer\'s annual income in local currency\n- Range: 20000.00 to 150000.00\n- Examples: 45000.0, 32000.0, 85000.0\n- Rules: Used for loan eligibility and credit limit determination\n\n**income_source** (nvarchar)\n- Description: Primary source of customer\'s income\n- Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance\n- Examples: Employment, Self-employment, Business\n- Rules: Affects income stability assessment for lending\n\n**income_category** (nvarchar)\n- Description: Income classification based on amount\n- Valid Values: Low, Medium, High\n- Examples: Low, Medium, High\n- Rules: Determines product offerings and credit limits\n\n**previous_loans_count** (int)\n- Description: Number of previous loans taken by the customer\n- Range: 0 to 5\n- Examples: 0, 2, 5\n- Rules: Higher count may affect future loan approval\n\n**credit_score** (int)\n- Description: Customer\'s credit score based on credit history\n- Range: 300 to 850\n- Examples: 718, 807, 511\n- Rules: Primary factor in loan approval and interest rate determination\n\n**loan_eligible** (bit)\n- Description: Boolean indicating if customer is eligible for loans\n- Valid Values: 0, 1\n- Examples: 1, 0\n- ...
# Result attributes: ['__annotations__', '__class__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'get_formatted_sources', 'metadata', 'response', 'source_nodes']
# Response attribute: <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Schema**: dbo
#
# ## Table: customer_information
# Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
#
# ### Table Structure
# **Full Name**: [dbo].[customer_information]
# **Primary Key**: id
#
# ### Column Definitions
#
# **id** (int)
# - Description: Unique customer identifier, 8-digit number
# - Range: 10000000 to 99999999
# - Examples: 10474206, 10962741, 13765547
# - Rules: Auto-generated unique identifier for each customer
#
# **full_name** (nvarchar)
# - Description: Customer's complete name (first and last name)
# - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
# - Rules: Required field, contains customer's legal name
#
# **email** (nvarchar)
# - Description: Customer's email address for communication
# - Examples: nelsoneddie@example.net, dillonjodi@example.net
# - Rules: Must be valid email format, used for notifications
#
# **phone_number** (nvarchar)
# - Description: Customer's contact phone number
# - Examples: +1-555-123-4567, (555) 987-6543
# - Rules: Various formats accepted, primary contact method
#
# **address** (nvarchar)
# - Description: Customer's physical address (street, city, state, zip)
# - Examples: 123 Main St, Anytown, ST 12345
# - Rules: Complete postal address for correspondence
#
# **account_number** (nvarchar)
# - Description: Bank account number associated with the customer
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit unique account identifier
#
# **account_type** (nvarchar)
# - Description: Type of bank account held by the customer
# - Valid Values: Savings, Cheque, Business
# - Examples: Savings, Cheque, Business
# - Rules: Determines account features and limitations
#
# **balance** (decimal)
# - Description: Current account balance in local currency
# - Range: 100.00 to 50000.00
# - Examples: 8383.72, 19437.26, 45030.79
# - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# **gender** (nvarchar)
# - Description: Customer's gender identification
# - Valid Values: Male, Female
# - Examples: Male, Female
# - Rules: Used for demographic analysis and targeted marketing
#
# **age** (int)
# - Description: Customer's age in years
# - Range: 18 to 75
# - Examples: 61, 30, 64
# - Rules: Must be 18+ to open account, affects product eligibility
#
# **occupation** (nvarchar)
# - Description: Customer's current job title or profession
# - Examples: English as a second language teacher, Engineering geologist, Information systems manager
# - Rules: Used for risk assessment and income verification
#
# **income** (decimal)
# - Description: Customer's annual income in local currency
# - Range: 20000.00 to 150000.00
# - Examples: 45000.0, 32000.0, 85000.0
# - Rules: Used for loan eligibility and credit limit determination
#
# **income_source** (nvarchar)
# - Description: Primary source of customer's income
# - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
# - Examples: Employment, Self-employment, Business
# - Rules: Affects income stability assessment for lending
#
# **income_category** (nvarchar)
# - Description: Income classification based on amount
# - Valid Values: Low, Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1, 0
# - Rules: Determines access to lending products
#
# **eligible_loan_amount** (decimal)
# - Description: Maximum loan amount customer is eligible for
# - Examples: 25000.0, 50000.0, 100000.0
# - Rules: Sets upper limit for loan applications
#
# **loan_amount_applied_for** (decimal)
# - Description: Amount of loan currently applied for or received
# - Examples: 15000.0, 30000.0, 0.0
# - Rules: Cannot exceed eligible_loan_amount, 0 if no loan application
#
# **loan_status** (nvarchar)
# - Description: Current status of loan application or existing loan
# - Valid Values: Pending, Approved, Active, Closed, None
# - Examples: Active, Pending, Approved
# - Rules: NULL if no loan application
#
# **loan_tenure** (int)
# - Description: Loan repayment period in months
# - Range: 6 to 60 months
# - Examples: 12, 24, 60
# - Rules: Longer tenure increases interest rate, NULL if no loan
#
# **loan_interest_rate** (decimal)
# - Description: Annual interest rate for the loan as a percentage
# - Range: 3.50% to 20.00%
# - Examples: 7.5, 12.25, 15.0
# - Rules: NULL if no loan, calculated using risk-based pricing
#
# **loan_purpose** (nvarchar)
# - Description: Reason for taking the loan
# - Valid Values: Home, Education, Vehicle, Personal, Business
# - Examples: Home, Education, Vehicle
# - Rules: Required for loan applications, affects interest rates
#
# **loan_application_date** (datetime)
# - Description: Date when loan application was submitted
# - Examples: 2023-05-15 10:30:00, 2024-01-20 14:45:00
# - Rules: NULL if no loan application, within last 2 years
#
# **last_login** (datetime)
# - Description: Last time customer accessed online banking
# - Examples: 2025-06-08 09:15:00, 2025-06-07 18:30:00
# - Rules: Used to track customer engagement and activity
#
# **product_holding** (nvarchar)
# - Description: JSON array of bank products held by the customer
# - Examples: ["Checking Account", "Overdraft Protection", "Foreign Currency Exchange"], ["Investment Advisory Services"], ["Home Mortgages", "Insurance Products", "Savings Account"]
# - Rules: Determines cross-selling opportunities and customer value
#
# **no_product_holding** (int)
# - Description: Count of products currently held by the customer
# - Range: 1 to 15
# - Examples: 3, 1, 9
# - Rules: Higher count indicates deeper customer relationship
#
# **entrenchment_score** (decimal)
# - Description: Percentage of total available products held by customer
# - Range: 0.00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# </end customer information metadata>
# Relevant tables retrieved successfully!
# <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Schema**: dbo
#
# ## Table: customer_information
# Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
#
# ### Table Structure
# **Full Name**: [dbo].[customer_information]
# **Primary Key**: id
#
# ### Column Definitions
#
# **id** (int)
# - Description: Unique customer identifier, 8-digit number
# - Range: 10000000 to 99999999
# - Examples: 10474206, 10962741, 13765547
# - Rules: Auto-generated unique identifier for each customer
#
# **full_name** (nvarchar)
# - Description: Customer's complete name (first and last name)
# - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
# - Rules: Required field, contains customer's legal name
#
# **email** (nvarchar)
# - Description: Customer's email address for communication
# - Examples: nelsoneddie@example.net, dillonjodi@example.net
# - Rules: Must be valid email format, used for notifications
#
# **phone_number** (nvarchar)
# - Description: Customer's contact phone number
# - Examples: +1-555-123-4567, (555) 987-6543
# - Rules: Various formats accepted, primary contact method
#
# **address** (nvarchar)
# - Description: Customer's physical address (street, city, state, zip)
# - Examples: 123 Main St, Anytown, ST 12345
# - Rules: Complete postal address for correspondence
#
# **account_number** (nvarchar)
# - Description: Bank account number associated with the customer
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit unique account identifier
#
# **account_type** (nvarchar)
# - Description: Type of bank account held by the customer
# - Valid Values: Savings, Cheque, Business
# - Examples: Savings, Cheque, Business
# - Rules: Determines account features and limitations
#
# **balance** (decimal)
# - Description: Current account balance in local currency
# - Range: 100.00 to 50000.00
# - Examples: 8383.72, 19437.26, 45030.79
# - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# **gender** (nvarchar)
# - Description: Customer's gender identification
# - Valid Values: Male, Female
# - Examples: Male, Female
# - Rules: Used for demographic analysis and targeted marketing
#
# **age** (int)
# - Description: Customer's age in years
# - Range: 18 to 75
# - Examples: 61, 30, 64
# - Rules: Must be 18+ to open account, affects product eligibility
#
# **occupation** (nvarchar)
# - Description: Customer's current job title or profession
# - Examples: English as a second language teacher, Engineering geologist, Information systems manager
# - Rules: Used for risk assessment and income verification
#
# **income** (decimal)
# - Description: Customer's annual income in local currency
# - Range: 20000.00 to 150000.00
# - Examples: 45000.0, 32000.0, 85000.0
# - Rules: Used for loan eligibility and credit limit determination
#
# **income_source** (nvarchar)
# - Description: Primary source of customer's income
# - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
# - Examples: Employment, Self-employment, Business
# - Rules: Affects income stability assessment for lending
#
# **income_category** (nvarchar)
# - Description: Income classification based on amount
# - Valid Values: Low, Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1, 0
# - Rules: Determines access to lending products
#
# **eligible_loan_amount** (decimal)
# - Description: Maximum loan amount customer is eligible for
# - Examples: 25000.0, 50000.0, 100000.0
# - Rules: Sets upper limit for loan applications
#
# **loan_amount_applied_for** (decimal)
# - Description: Amount of loan currently applied for or received
# - Examples: 15000.0, 30000.0, 0.0
# - Rules: Cannot exceed eligible_loan_amount, 0 if no loan application
#
# **loan_status** (nvarchar)
# - Description: Current status of loan application or existing loan
# - Valid Values: Pending, Approved, Active, Closed, None
# - Examples: Active, Pending, Approved
# - Rules: NULL if no loan application
#
# **loan_tenure** (int)
# - Description: Loan repayment period in months
# - Range: 6 to 60 months
# - Examples: 12, 24, 60
# - Rules: Longer tenure increases interest rate, NULL if no loan
#
# **loan_interest_rate** (decimal)
# - Description: Annual interest rate for the loan as a percentage
# - Range: 3.50% to 20.00%
# - Examples: 7.5, 12.25, 15.0
# - Rules: NULL if no loan, calculated using risk-based pricing
#
# **loan_purpose** (nvarchar)
# - Description: Reason for taking the loan
# - Valid Values: Home, Education, Vehicle, Personal, Business
# - Examples: Home, Education, Vehicle
# - Rules: Required for loan applications, affects interest rates
#
# **loan_application_date** (datetime)
# - Description: Date when loan application was submitted
# - Examples: 2023-05-15 10:30:00, 2024-01-20 14:45:00
# - Rules: NULL if no loan application, within last 2 years
#
# **last_login** (datetime)
# - Description: Last time customer accessed online banking
# - Examples: 2025-06-08 09:15:00, 2025-06-07 18:30:00
# - Rules: Used to track customer engagement and activity
#
# **product_holding** (nvarchar)
# - Description: JSON array of bank products held by the customer
# - Examples: ["Checking Account", "Overdraft Protection", "Foreign Currency Exchange"], ["Investment Advisory Services"], ["Home Mortgages", "Insurance Products", "Savings Account"]
# - Rules: Determines cross-selling opportunities and customer value
#
# **no_product_holding** (int)
# - Description: Count of products currently held by the customer
# - Range: 1 to 15
# - Examples: 3, 1, 9
# - Rules: Higher count indicates deeper customer relationship
#
# **entrenchment_score** (decimal)
# - Description: Percentage of total available products held by customer
# - Range: 0.00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# </end customer information metadata>

# %%
import json

def agent_table_rag(query):
    return query_engine.query("retrieve the full tables metadata without intepreting or editing anything for the following given tables: " + query)

def check_and_display_collection_info(client_db, collection_name_to_check):
    """
    Checks if a ChromaDB collection exists and displays its content if it does.
    Also lists all available collections.
    """
    print("\n--- ChromaDB Collection Information ---")

    # 1. List all collections
    print("Listing all collections:")
    all_collections = client_db.list_collections()
    if all_collections:
        for col in all_collections:
            print(f"- {col.name}")
    else:
        print("No collections found in the database.")

    # 2. Check if the specified collection exists
    print(f"\nChecking if collection '{collection_name_to_check}' exists...")
    try:
        target_collection = client_db.get_collection(collection_name_to_check)
        print(f"Collection '{collection_name_to_check}' exists!")

        # 3. Get and display some content from the index
        print(f"\nDisplaying first 5 items from '{collection_name_to_check}':")
        # Use peek() to get a small sample of the collection's contents
        # It returns a dictionary with 'ids', 'embeddings', 'metadatas', 'documents'
        # We are primarily interested in 'documents' and 'metadatas' for content.
        collection_content = target_collection.peek(limit=5)

        if collection_content and collection_content.get('documents'):
            for i, doc in enumerate(collection_content['documents']):
                print(f"--- Item {i+1} ---")
                print(f"ID: {collection_content['ids'][i]}")
                print(f"Document: {doc}")
                if collection_content.get('metadatas') and collection_content['metadatas'][i]:
                    print(f"Metadata: {json.dumps(collection_content['metadatas'][i], indent=2)}")
                print("-" * 20)
        else:
            print(f"Collection '{collection_name_to_check}' is empty or has no documents.")

    except chromadb.exceptions.CollectionNotFoundError:
        print(f"Collection '{collection_name_to_check}' does NOT exist.")
    except Exception as e:
        print(f"An error occurred while accessing collection '{collection_name_to_check}': {e}")
    print("-------------------------------------")


if __name__ == "__main__":
    # Call the new function to check and display collection info
    check_and_display_collection_info(db, "sql_tables_metadata")
    # check_and_display_collection_info(db, "non_existent_collection") # Example for a non-existent collection

    user_request = "customer information"
    try:
        print("\nRetrieving relevant tables for the request:", user_request)
        table_results = agent_table_rag(user_request)
        print("Type of result:", type(table_results))
        print("Raw result:", repr(table_results))
        if not table_results:
            print("No results returned from query.")
        else:
            # If it's not a string, print its attributes
            if not isinstance(table_results, str):
                print("Result attributes:", dir(table_results))
                # Try to print a 'response' or 'text' attribute if present
                if hasattr(table_results, 'response'):
                    print("Response attribute:", table_results.response)
                if hasattr(table_results, 'text'):
                    print("Text attribute:", table_results.text)
            print("Relevant tables retrieved successfully!")
            print(table_results)
    except Exception as e:
        print(f"Error retrieving tables: {e}")
# Out:
# --- ChromaDB Collection Information ---
# Listing all collections:
# - sql_tables_metadata
#
# Checking if collection 'sql_tables_metadata' exists...
# Collection 'sql_tables_metadata' exists!
#
# Displaying first 5 items from 'sql_tables_metadata':
# --- Item 1 ---
# ID: ffe71549-4d19-4da1-9813-8454a82b6dd4
# Document: <begin transaction history metadata>
#
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Server**: localhost\SQLEXPRESS
# - **Schema**: dbo
#
# ## Table: transaction_history
# Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases
#
# ### Table Structure
# **Full Name**: [dbo].[transaction_history]
# **Records**: 5000+ transactions
# **Primary Key**: transaction_id
# **Foreign Keys**: customer_id
# **Time Range**: Last 2 years of transaction data
#
# ### Column Definitions
#
# **transaction_id** (bigint)
# - Description: Unique transaction identifier, 12-digit number
# - Range: 100000000000 to 999999999999
# - Examples: 679551814302, 376513881618, 994709101726
# - Rules: Auto-generated unique identifier for each transaction
#
# **customer_id** (int)
# - Description: Customer identifier linking to customer_information table
# - Range: 10000000 to 99999999
# - Examples: 10000001, 10000002, 10000003
# - Rules: Must exist in customer_information table
#
# **transaction_date** (datetime)
# - Description: Date and time when the transaction occurred
# - Examples: 2023-06-15 14:30:22, 2024-11-28 09:15:45, 2025-01-12 16:45:33
# - Rules: Cannot be future date, used for transaction ordering and reporting
#
# **transaction_type** (nvarchar)
# - Description: Type of transaction performed
# - Valid Values: Deposit, Withdrawal, Transfer, Payment, Purchase, Refund, Fee, Interest, Loan Payment, Salary
# - Examples: Deposit, Withdrawal, Transfer
# - Rules: Determines transaction processing rules and account impact
#
# **amount** (decimal)
# - Description: Transaction amount in specified currency (negative for debits, positive for credits)
# - Range: -100000.00 to 100000.00
# - Examples: 1500.5, -89.99, 25000.0
# - Rules: Negative values represent debits (withdrawals, payments, fees), positive values represent credits (deposits, refunds, interest)
#
# **currency** (nvarchar)
# - Description: ISO 4217 currency code for the transaction
# - Valid Values: ZAR, USD, EUR, GBP, JPY
# - Examples: ZAR, USD, EUR
# - Rules: Primarily ZAR (85%), with some international currencies for forex transactions
#
# **description** (nvarchar)
# - Description: Human-readable description of the transaction
# - Examples: Groceries purchase at Woolworths, Transfer to John Smith, Salary payment from ABC Corp
# - Rules: Auto-generated based on transaction type and context
#
# **category** (nvarchar)
# - Description: Transaction category for spending analysis
# - Valid Values: Groceries, Gas, Restaurant, Shopping, Utilities, Healthcare, Entertainment, Travel, Education, Insurance, Banking, Investment, Salary, Bonus, Refund, Other
# - Examples: Groceries, Gas, Restaurant
# - Rules: Used for budgeting and spending pattern analysis
#
# **channel** (nvarchar)
# - Description: Channel through which the transaction was made
# - Valid Values: ATM, Online Banking, Mobile App, Branch, POS Terminal, Wire Transfer, ACH, Check, Direct Deposit
# - Examples: ATM, Online Banking, Mobile App
# - Rules: Tracks customer behavior and channel preference
#
# **status** (nvarchar)
# - Description: Current status of the transaction
# - Valid Values: Completed, Pending, Failed, Cancelled
# - Examples: Completed, Pending, Failed
# - Rules: Only Completed transactions affect account balance
#
# **reference_number** (nvarchar)
# - Description: Unique reference number for transaction tracking
# - Examples: REF1234AB5678, REF9876XY1234
# - Rules: Used for transaction inquiries and dispute resolution
# - Pattern: REF####?
# Metadata: {
#   "confidentiality": "high",
#   "ref_doc_id": "0e8acbcf-b169-404d-9369-abb8bfdcfe0e",
#   "document_id": "0e8acbcf-b169-404d-9369-abb8bfdcfe0e",
#   "_node_type": "TextNode",
#   "description": "Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases",
#   "department": "Finance",
#   "_node_content": "{\"id_\": \"ffe71549-4d19-4da1-9813-8454a82b6dd4\", \"embedding\": null, \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"0e8acbcf-b169-404d-9369-abb8bfdcfe0e\", \"node_type\": \"4\", \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"hash\": \"ed4701490b48486ed69fd0859fe4fcd7195fb9c13f2d6561753ac54cbcb3a80b\", \"class_name\": \"RelatedNodeInfo\"}, \"3\": {\"node_id\": \"49199bf2-dd46-45a1-8131-a63b9ee0e24d\", \"node_type\": \"1\", \"metadata\": {}, \"hash\": \"e515675f5abadcd730421462487e6a6f673f0fea415b76ae87b9dde9bb85f4ee\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 0, \"end_char_idx\": 3592, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "category": "transaction history table",
#   "doc_id": "0e8acbcf-b169-404d-9369-abb8bfdcfe0e",
#   "year": "2025-07-20",
#   "author": "Mzwandile Mhlongo"
# }
# --------------------
# --- Item 2 ---
# ID: 49199bf2-dd46-45a1-8131-a63b9ee0e24d
# Document: ?####
#
# **merchant_name** (nvarchar)
# - Description: Name of merchant for purchase and payment transactions
# - Examples: Woolworths, Shell Garage, Amazon
# - Rules: Only populated for Purchase and Payment transaction types
#
# **merchant_category** (nvarchar)
# - Description: Category of merchant for purchase and payment transactions
# - Examples: Groceries, Gas, Shopping
# - Rules: Matches category field for Purchase and Payment transactions
#
# **account_from** (nvarchar)
# - Description: Source account number for the transaction
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit account number, links to customer's account
#
# **account_to** (nvarchar)
# - Description: Destination account number for transfer transactions
# - Examples: 5555666677, 1111222233
# - Rules: Only populated for Transfer transaction types
#
# **balance_after** (decimal)
# - Description: Account balance after the transaction was processed
# - Range: 0.00 to 100000.00
# - Examples: 15420.5, 8750.25, 45000.0
# - Rules: Snapshot of balance immediately after transaction completion
#
# **location** (nvarchar)
# - Description: Geographic location where the transaction occurred
# - Examples: Johannesburg, South Africa, Cape Town, South Africa, London, United Kingdom
# - Rules: Used for fraud detection and geographic spending analysis
#
# **created_at** (datetime)
# - Description: Timestamp when the transaction record was created in the system
# - Examples: 2025-06-09 10:30:22, 2025-06-09 11:15:45
# - Rules: System audit field, automatically populated
#
# **updated_at** (datetime)
# - Description: Timestamp when the transaction record was last updated
# - Examples: 2025-06-09 10:30:22, 2025-06-09 11:15:45
# - Rules: System audit field, automatically updated on changes
#
# ### Key Relationships & Rules
#
# - **customer_id** references **customer_information.id**: Each transaction belongs to one customer, customers can have many transactions
# - **merchant_name** depends on **transaction_type**: merchant_name is only populated when transaction_type is 'Purchase' or 'Payment'
# - **account_to** depends on **transaction_type**: account_to is only populated when transaction_type is 'Transfer'
# - **Amount Sign Convention**: Negative amounts for debits (Withdrawal, Payment, Purchase, Fee, Loan Payment), positive for credits (Deposit, Salary, Interest, Refund)
# - **Status Constraint**: balance_after only reflects completed transactions, not pending/failed ones
#
# </end transaction history metadata>
# Metadata: {
#   "doc_id": "0e8acbcf-b169-404d-9369-abb8bfdcfe0e",
#   "description": "Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases",
#   "author": "Mzwandile Mhlongo",
#   "category": "transaction history table",
#   "_node_type": "TextNode",
#   "year": "2025-07-20",
#   "ref_doc_id": "0e8acbcf-b169-404d-9369-abb8bfdcfe0e",
#   "department": "Finance",
#   "confidentiality": "high",
#   "document_id": "0e8acbcf-b169-404d-9369-abb8bfdcfe0e",
#   "_node_content": "{\"id_\": \"49199bf2-dd46-45a1-8131-a63b9ee0e24d\", \"embedding\": null, \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"0e8acbcf-b169-404d-9369-abb8bfdcfe0e\", \"node_type\": \"4\", \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"hash\": \"ed4701490b48486ed69fd0859fe4fcd7195fb9c13f2d6561753ac54cbcb3a80b\", \"class_name\": \"RelatedNodeInfo\"}, \"2\": {\"node_id\": \"ffe71549-4d19-4da1-9813-8454a82b6dd4\", \"node_type\": \"1\", \"metadata\": {\"category\": \"transaction history table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases\"}, \"hash\": \"f092181a5af30d1ab1231e9128a7dfa01fd8ee517fc7ba5bf6e521042b6c7a3d\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 3592, \"end_char_idx\": 6067, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}"
# }
# --------------------
# --- Item 3 ---
# ID: 444322a2-17be-4c24-b32a-1a5d2a8898d7
# Document: <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Schema**: dbo
#
# ## Table: customer_information
# Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
#
# ### Table Structure
# **Full Name**: [dbo].[customer_information]
# **Primary Key**: id
#
# ### Column Definitions
#
# **id** (int)
# - Description: Unique customer identifier, 8-digit number
# - Range: 10000000 to 99999999
# - Examples: 10474206, 10962741, 13765547
# - Rules: Auto-generated unique identifier for each customer
#
# **full_name** (nvarchar)
# - Description: Customer's complete name (first and last name)
# - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
# - Rules: Required field, contains customer's legal name
#
# **email** (nvarchar)
# - Description: Customer's email address for communication
# - Examples: nelsoneddie@example.net, dillonjodi@example.net
# - Rules: Must be valid email format, used for notifications
#
# **phone_number** (nvarchar)
# - Description: Customer's contact phone number
# - Examples: +1-555-123-4567, (555) 987-6543
# - Rules: Various formats accepted, primary contact method
#
# **address** (nvarchar)
# - Description: Customer's physical address (street, city, state, zip)
# - Examples: 123 Main St, Anytown, ST 12345
# - Rules: Complete postal address for correspondence
#
# **account_number** (nvarchar)
# - Description: Bank account number associated with the customer
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit unique account identifier
#
# **account_type** (nvarchar)
# - Description: Type of bank account held by the customer
# - Valid Values: Savings, Cheque, Business
# - Examples: Savings, Cheque, Business
# - Rules: Determines account features and limitations
#
# **balance** (decimal)
# - Description: Current account balance in local currency
# - Range: 100.00 to 50000.00
# - Examples: 8383.72, 19437.26, 45030.79
# - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# **gender** (nvarchar)
# - Description: Customer's gender identification
# - Valid Values: Male, Female
# - Examples: Male, Female
# - Rules: Used for demographic analysis and targeted marketing
#
# **age** (int)
# - Description: Customer's age in years
# - Range: 18 to 75
# - Examples: 61, 30, 64
# - Rules: Must be 18+ to open account, affects product eligibility
#
# **occupation** (nvarchar)
# - Description: Customer's current job title or profession
# - Examples: English as a second language teacher, Engineering geologist, Information systems manager
# - Rules: Used for risk assessment and income verification
#
# **income** (decimal)
# - Description: Customer's annual income in local currency
# - Range: 20000.00 to 150000.00
# - Examples: 45000.0, 32000.0, 85000.0
# - Rules: Used for loan eligibility and credit limit determination
#
# **income_source** (nvarchar)
# - Description: Primary source of customer's income
# - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
# - Examples: Employment, Self-employment, Business
# - Rules: Affects income stability assessment for lending
#
# **income_category** (nvarchar)
# - Description: Income classification based on amount
# - Valid Values: Low, Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1,
# Metadata: {
#   "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers",
#   "ref_doc_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "document_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "doc_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "_node_content": "{\"id_\": \"444322a2-17be-4c24-b32a-1a5d2a8898d7\", \"embedding\": null, \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe\", \"node_type\": \"4\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"dda5eb6f7dcc5abd58eafb75713640da6e17d9a6406ad9bd87939bd68869aa12\", \"class_name\": \"RelatedNodeInfo\"}, \"3\": {\"node_id\": \"325a8ba2-2e5b-4fb0-8ab8-a0e771a291e5\", \"node_type\": \"1\", \"metadata\": {}, \"hash\": \"f26ab155d073ac962fabe9dfed35b32cd291c161325eaef1f2b3540b5262e2bc\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 2, \"end_char_idx\": 3955, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "_node_type": "TextNode",
#   "category": "customer information table",
#   "year": "2025-07-20",
#   "author": "Mzwandile Mhlongo",
#   "department": "Finance",
#   "confidentiality": "high"
# }
# --------------------
# --- Item 4 ---
# ID: 325a8ba2-2e5b-4fb0-8ab8-a0e771a291e5
# Document: Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1, 0
# - Rules: Determines access to lending products
#
# **eligible_loan_amount** (decimal)
# - Description: Maximum loan amount customer is eligible for
# - Examples: 25000.0, 50000.0, 100000.0
# - Rules: Sets upper limit for loan applications
#
# **loan_amount_applied_for** (decimal)
# - Description: Amount of loan currently applied for or received
# - Examples: 15000.0, 30000.0, 0.0
# - Rules: Cannot exceed eligible_loan_amount, 0 if no loan application
#
# **loan_status** (nvarchar)
# - Description: Current status of loan application or existing loan
# - Valid Values: Pending, Approved, Active, Closed, None
# - Examples: Active, Pending, Approved
# - Rules: NULL if no loan application
#
# **loan_tenure** (int)
# - Description: Loan repayment period in months
# - Range: 6 to 60 months
# - Examples: 12, 24, 60
# - Rules: Longer tenure increases interest rate, NULL if no loan
#
# **loan_interest_rate** (decimal)
# - Description: Annual interest rate for the loan as a percentage
# - Range: 3.50% to 20.00%
# - Examples: 7.5, 12.25, 15.0
# - Rules: NULL if no loan, calculated using risk-based pricing
#
# **loan_purpose** (nvarchar)
# - Description: Reason for taking the loan
# - Valid Values: Home, Education, Vehicle, Personal, Business
# - Examples: Home, Education, Vehicle
# - Rules: Required for loan applications, affects interest rates
#
# **loan_application_date** (datetime)
# - Description: Date when loan application was submitted
# - Examples: 2023-05-15 10:30:00, 2024-01-20 14:45:00
# - Rules: NULL if no loan application, within last 2 years
#
# **last_login** (datetime)
# - Description: Last time customer accessed online banking
# - Examples: 2025-06-08 09:15:00, 2025-06-07 18:30:00
# - Rules: Used to track customer engagement and activity
#
# **product_holding** (nvarchar)
# - Description: JSON array of bank products held by the customer
# - Examples: ["Checking Account", "Overdraft Protection", "Foreign Currency Exchange"], ["Investment Advisory Services"], ["Home Mortgages", "Insurance Products", "Savings Account"]
# - Rules: Determines cross-selling opportunities and customer value
#
# **no_product_holding** (int)
# - Description: Count of products currently held by the customer
# - Range: 1 to 15
# - Examples: 3, 1, 9
# - Rules: Higher count indicates deeper customer relationship
#
# **entrenchment_score** (decimal)
# - Description: Percentage of total available products held by customer
# - Range: 0.00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score,
# Metadata: {
#   "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers",
#   "confidentiality": "high",
#   "_node_content": "{\"id_\": \"325a8ba2-2e5b-4fb0-8ab8-a0e771a291e5\", \"embedding\": null, \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe\", \"node_type\": \"4\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"dda5eb6f7dcc5abd58eafb75713640da6e17d9a6406ad9bd87939bd68869aa12\", \"class_name\": \"RelatedNodeInfo\"}, \"2\": {\"node_id\": \"444322a2-17be-4c24-b32a-1a5d2a8898d7\", \"node_type\": \"1\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"a1ad7bc4bf9ce28e24f546d53c0befa82d04f4aa2135430b4a86105391181c42\", \"class_name\": \"RelatedNodeInfo\"}, \"3\": {\"node_id\": \"488b5e15-cee0-45bd-a383-17ea8b8191d0\", \"node_type\": \"1\", \"metadata\": {}, \"hash\": \"909dd97a752f6ee33d1c9d12fd157f3b699fcf0d72895c4b0eacf1504f273e1a\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 3319, \"end_char_idx\": 7051, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}",
#   "year": "2025-07-20",
#   "category": "customer information table",
#   "document_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "department": "Finance",
#   "author": "Mzwandile Mhlongo",
#   "ref_doc_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "_node_type": "TextNode",
#   "doc_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe"
# }
# --------------------
# --- Item 5 ---
# ID: 488b5e15-cee0-45bd-a383-17ea8b8191d0
# Document: 00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# </end customer information metadata>
# Metadata: {
#   "author": "Mzwandile Mhlongo",
#   "_node_type": "TextNode",
#   "confidentiality": "high",
#   "description": "Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers",
#   "department": "Finance",
#   "ref_doc_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "doc_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "category": "customer information table",
#   "year": "2025-07-20",
#   "document_id": "4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe",
#   "_node_content": "{\"id_\": \"488b5e15-cee0-45bd-a383-17ea8b8191d0\", \"embedding\": null, \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"excluded_embed_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"excluded_llm_metadata_keys\": [\"file_name\", \"file_type\", \"file_size\", \"creation_date\", \"last_modified_date\", \"last_accessed_date\"], \"relationships\": {\"1\": {\"node_id\": \"4b7f4ef6-db96-4dcd-ba5b-da5dab2044fe\", \"node_type\": \"4\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"dda5eb6f7dcc5abd58eafb75713640da6e17d9a6406ad9bd87939bd68869aa12\", \"class_name\": \"RelatedNodeInfo\"}, \"2\": {\"node_id\": \"325a8ba2-2e5b-4fb0-8ab8-a0e771a291e5\", \"node_type\": \"1\", \"metadata\": {\"category\": \"customer information table\", \"year\": \"2025-07-20\", \"department\": \"Finance\", \"author\": \"Mzwandile Mhlongo\", \"confidentiality\": \"high\", \"description\": \"Comprehensive customer information data table containing personal information, financial details, loan information, and product holdings for bank customers\"}, \"hash\": \"e1b42aa09ee1b83a06ff13ff0bad1f2b0a013b7f5be7adf9c990baf0a6e1feed\", \"class_name\": \"RelatedNodeInfo\"}}, \"metadata_template\": \"{key}: {value}\", \"metadata_separator\": \"\\n\", \"text\": \"\", \"mimetype\": \"text/plain\", \"start_char_idx\": 6361, \"end_char_idx\": 7116, \"metadata_seperator\": \"\\n\", \"text_template\": \"{metadata_str}\\n\\n{content}\", \"class_name\": \"TextNode\"}"
# }
# --------------------
# -------------------------------------
#
# Retrieving relevant tables for the request: customer information
# Type of result: <class 'llama_index.core.base.response.schema.Response'>
# Raw result: Response(response="<begin customer information metadata>\r\n# Database Schema Information\r\n\r\n## Database Details\r\n- **Database**: SQL Server (master)\r\n- **Schema**: dbo\r\n\r\n## Table: customer_information\r\nComprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers\r\n\r\n### Table Structure\r\n**Full Name**: [dbo].[customer_information]\r\n**Primary Key**: id\r\n\r\n### Column Definitions\r\n\r\n**id** (int)\r\n- Description: Unique customer identifier, 8-digit number\r\n- Range: 10000000 to 99999999\r\n- Examples: 10474206, 10962741, 13765547\r\n- Rules: Auto-generated unique identifier for each customer\r\n\r\n**full_name** (nvarchar)\r\n- Description: Customer's complete name (first and last name)\r\n- Examples: Rachel Benitez, Samuel Anderson, Austin Perkins\r\n- Rules: Required field, contains customer's legal name\r\n\r\n**email** (nvarchar)\r\n- Description: Customer's email address for communication\r\n- Examples: nelsoneddie@example.net, dillonjodi@example.net\r\n- Rules: Must be valid email format, used for notifications\r\n\r\n**phone_number** (nvarchar)\r\n- Description: Customer's contact phone number\r\n- Examples: +1-555-123-4567, (555) 987-6543\r\n- Rules: Various formats accepted, primary contact method\r\n\r\n**address** (nvarchar)\r\n- Description: Customer's physical address (street, city, state, zip)\r\n- Examples: 123 Main St, Anytown, ST 12345\r\n- Rules: Complete postal address for correspondence\r\n\r\n**account_number** (nvarchar)\r\n- Description: Bank account number associated with the customer\r\n- Examples: 1234567890, 9876543210\r\n- Rules: 10-digit unique account identifier\r\n\r\n**account_type** (nvarchar)\r\n- Description: Type of bank account held by the customer\r\n- Valid Values: Savings, Cheque, Business\r\n- Examples: Savings, Cheque, Business\r\n- Rules: Determines account features and limitations\r\n\r\n**balance** (decimal)\r\n- Description: Current account balance in local currency\r\n- Range: 100.00 to 50000.00\r\n- Examples: 8383.72, 19437.26, 45030.79\r\n- Rules: Updated in real-time with transactions, minimum balance varies by account type\r\n\r\n**gender** (nvarchar)\r\n- Description: Customer's gender identification\r\n- Valid Values: Male, Female\r\n- Examples: Male, Female\r\n- Rules: Used for demographic analysis and targeted marketing\r\n\r\n**age** (int)\r\n- Description: Customer's age in years\r\n- Range: 18 to 75\r\n- Examples: 61, 30, 64\r\n- Rules: Must be 18+ to open account, affects product eligibility\r\n\r\n**occupation** (nvarchar)\r\n- Description: Customer's current job title or profession\r\n- Examples: English as a second language teacher, Engineering geologist, Information systems manager\r\n- Rules: Used for risk assessment and income verification\r\n\r\n**income** (decimal)\r\n- Description: Customer's annual income in local currency\r\n- Range: 20000.00 to 150000.00\r\n- Examples: 45000.0, 32000.0, 85000.0\r\n- Rules: Used for loan eligibility and credit limit determination\r\n\r\n**income_source** (nvarchar)\r\n- Description: Primary source of customer's income\r\n- Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance\r\n- Examples: Employment, Self-employment, Business\r\n- Rules: Affects income stability assessment for lending\r\n\r\n**income_category** (nvarchar)\r\n- Description: Income classification based on amount\r\n- Valid Values: Low, Medium, High\r\n- Examples: Low, Medium, High\r\n- Rules: Determines product offerings and credit limits\r\n\r\n**previous_loans_count** (int)\r\n- Description: Number of previous loans taken by the customer\r\n- Range: 0 to 5\r\n- Examples: 0, 2, 5\r\n- Rules: Higher count may affect future loan approval\r\n\r\n**credit_score** (int)\r\n- Description: Customer's credit score based on credit history\r\n- Range: 300 to 850\r\n- Examples: 718, 807, 511\r\n- Rules: Prima ...
# Result attributes: ['__annotations__', '__class__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'get_formatted_sources', 'metadata', 'response', 'source_nodes']
# Response attribute: <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Schema**: dbo
#
# ## Table: customer_information
# Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
#
# ### Table Structure
# **Full Name**: [dbo].[customer_information]
# **Primary Key**: id
#
# ### Column Definitions
#
# **id** (int)
# - Description: Unique customer identifier, 8-digit number
# - Range: 10000000 to 99999999
# - Examples: 10474206, 10962741, 13765547
# - Rules: Auto-generated unique identifier for each customer
#
# **full_name** (nvarchar)
# - Description: Customer's complete name (first and last name)
# - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
# - Rules: Required field, contains customer's legal name
#
# **email** (nvarchar)
# - Description: Customer's email address for communication
# - Examples: nelsoneddie@example.net, dillonjodi@example.net
# - Rules: Must be valid email format, used for notifications
#
# **phone_number** (nvarchar)
# - Description: Customer's contact phone number
# - Examples: +1-555-123-4567, (555) 987-6543
# - Rules: Various formats accepted, primary contact method
#
# **address** (nvarchar)
# - Description: Customer's physical address (street, city, state, zip)
# - Examples: 123 Main St, Anytown, ST 12345
# - Rules: Complete postal address for correspondence
#
# **account_number** (nvarchar)
# - Description: Bank account number associated with the customer
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit unique account identifier
#
# **account_type** (nvarchar)
# - Description: Type of bank account held by the customer
# - Valid Values: Savings, Cheque, Business
# - Examples: Savings, Cheque, Business
# - Rules: Determines account features and limitations
#
# **balance** (decimal)
# - Description: Current account balance in local currency
# - Range: 100.00 to 50000.00
# - Examples: 8383.72, 19437.26, 45030.79
# - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# **gender** (nvarchar)
# - Description: Customer's gender identification
# - Valid Values: Male, Female
# - Examples: Male, Female
# - Rules: Used for demographic analysis and targeted marketing
#
# **age** (int)
# - Description: Customer's age in years
# - Range: 18 to 75
# - Examples: 61, 30, 64
# - Rules: Must be 18+ to open account, affects product eligibility
#
# **occupation** (nvarchar)
# - Description: Customer's current job title or profession
# - Examples: English as a second language teacher, Engineering geologist, Information systems manager
# - Rules: Used for risk assessment and income verification
#
# **income** (decimal)
# - Description: Customer's annual income in local currency
# - Range: 20000.00 to 150000.00
# - Examples: 45000.0, 32000.0, 85000.0
# - Rules: Used for loan eligibility and credit limit determination
#
# **income_source** (nvarchar)
# - Description: Primary source of customer's income
# - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
# - Examples: Employment, Self-employment, Business
# - Rules: Affects income stability assessment for lending
#
# **income_category** (nvarchar)
# - Description: Income classification based on amount
# - Valid Values: Low, Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1,
#
# 00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# </end customer information metadata>
# Relevant tables retrieved successfully!
# <begin customer information metadata>
# # Database Schema Information
#
# ## Database Details
# - **Database**: SQL Server (master)
# - **Schema**: dbo
#
# ## Table: customer_information
# Comprehensive customer data table containing personal information, financial details, loan information, and product holdings for bank customers
#
# ### Table Structure
# **Full Name**: [dbo].[customer_information]
# **Primary Key**: id
#
# ### Column Definitions
#
# **id** (int)
# - Description: Unique customer identifier, 8-digit number
# - Range: 10000000 to 99999999
# - Examples: 10474206, 10962741, 13765547
# - Rules: Auto-generated unique identifier for each customer
#
# **full_name** (nvarchar)
# - Description: Customer's complete name (first and last name)
# - Examples: Rachel Benitez, Samuel Anderson, Austin Perkins
# - Rules: Required field, contains customer's legal name
#
# **email** (nvarchar)
# - Description: Customer's email address for communication
# - Examples: nelsoneddie@example.net, dillonjodi@example.net
# - Rules: Must be valid email format, used for notifications
#
# **phone_number** (nvarchar)
# - Description: Customer's contact phone number
# - Examples: +1-555-123-4567, (555) 987-6543
# - Rules: Various formats accepted, primary contact method
#
# **address** (nvarchar)
# - Description: Customer's physical address (street, city, state, zip)
# - Examples: 123 Main St, Anytown, ST 12345
# - Rules: Complete postal address for correspondence
#
# **account_number** (nvarchar)
# - Description: Bank account number associated with the customer
# - Examples: 1234567890, 9876543210
# - Rules: 10-digit unique account identifier
#
# **account_type** (nvarchar)
# - Description: Type of bank account held by the customer
# - Valid Values: Savings, Cheque, Business
# - Examples: Savings, Cheque, Business
# - Rules: Determines account features and limitations
#
# **balance** (decimal)
# - Description: Current account balance in local currency
# - Range: 100.00 to 50000.00
# - Examples: 8383.72, 19437.26, 45030.79
# - Rules: Updated in real-time with transactions, minimum balance varies by account type
#
# **gender** (nvarchar)
# - Description: Customer's gender identification
# - Valid Values: Male, Female
# - Examples: Male, Female
# - Rules: Used for demographic analysis and targeted marketing
#
# **age** (int)
# - Description: Customer's age in years
# - Range: 18 to 75
# - Examples: 61, 30, 64
# - Rules: Must be 18+ to open account, affects product eligibility
#
# **occupation** (nvarchar)
# - Description: Customer's current job title or profession
# - Examples: English as a second language teacher, Engineering geologist, Information systems manager
# - Rules: Used for risk assessment and income verification
#
# **income** (decimal)
# - Description: Customer's annual income in local currency
# - Range: 20000.00 to 150000.00
# - Examples: 45000.0, 32000.0, 85000.0
# - Rules: Used for loan eligibility and credit limit determination
#
# **income_source** (nvarchar)
# - Description: Primary source of customer's income
# - Valid Values: Employment, Self-employment, Business, Investments, Pension, Rental, Freelance
# - Examples: Employment, Self-employment, Business
# - Rules: Affects income stability assessment for lending
#
# **income_category** (nvarchar)
# - Description: Income classification based on amount
# - Valid Values: Low, Medium, High
# - Examples: Low, Medium, High
# - Rules: Determines product offerings and credit limits
#
# **previous_loans_count** (int)
# - Description: Number of previous loans taken by the customer
# - Range: 0 to 5
# - Examples: 0, 2, 5
# - Rules: Higher count may affect future loan approval
#
# **credit_score** (int)
# - Description: Customer's credit score based on credit history
# - Range: 300 to 850
# - Examples: 718, 807, 511
# - Rules: Primary factor in loan approval and interest rate determination
#
# **loan_eligible** (bit)
# - Description: Boolean indicating if customer is eligible for loans
# - Valid Values: 0, 1
# - Examples: 1,
#
# 00% to 100.00%
# - Examples: 13.04, 4.35, 39.13
# - Rules: Higher score indicates stronger customer relationship and retention likelihood
#
# ### Key Relationships & Rules
#
# - **loan_eligible** is calculated from **credit_score**: loan_eligible = 1 if credit_score >= 580, else 0
# - **income_category** is calculated from **income**: Low: <30K, Medium: 30K-70K, High: >70K
# - **no_product_holding** is calculated from **product_holding**: COUNT of JSON array items
# - **entrenchment_score** is calculated from **no_product_holding**: (no_product_holding / 23) * 100
# - Constraint: loan_amount_applied_for <= eligible_loan_amount
# - Constraint: loan_interest_rate calculated from credit_score, loan_tenure, loan_amount
#
# </end customer information metadata>

# %%
generate_response("generate the full table details without intepreting or editing anything: transaction history full table details")
# Out:
# **Query:**
#  generate the full table details without intepreting or editing anything: transaction history full table details
#
# **Answer:**
#  Database: SQL Server (master)
# Server: localhost\SQLEXPRESS
# Schema: dbo
#
# Table: [dbo].[transaction_history]
# Description: Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases
# Records: 5000+ transactions
# Primary Key: transaction_id
# Foreign Keys: customer_id
# Time Range: Last 2 years of transaction data
#
# Column Definitions:
#
# - transaction_id (bigint)
#   - Description: Unique transaction identifier, 12-digit number
#   - Range: 100000000000 to 999999999999
#   - Examples: 679551814302, 376513881618, 994709101726
#   - Rules: Auto-generated unique identifier for each transaction
#
# - customer_id (int)
#   - Description: Customer identifier linking to customer_information table
#   - Range: 10000000 to 99999999
#   - Examples: 10000001, 10000002, 10000003
#   - Rules: Must exist in customer_information table
#
# - transaction_date (datetime)
#   - Description: Date and time when the transaction occurred
#   - Examples: 2023-06-15 14:30:22, 2024-11-28 09:15:45, 2025-01-12 16:45:33
#   - Rules: Cannot be future date, used for transaction ordering and reporting
#
# - transaction_type (nvarchar)
#   - Description: Type of transaction performed
#   - Valid Values: Deposit, Withdrawal, Transfer, Payment, Purchase, Refund, Fee, Interest, Loan Payment, Salary
#   - Examples: Deposit, Withdrawal, Transfer
#   - Rules: Determines transaction processing rules and account impact
#
# - amount (decimal)
#   - Description: Transaction amount in specified currency (negative for debits, positive for credits)
#   - Range: -100000.00 to 100000.00
#   - Examples: 1500.5, -89.99, 25000.0
#   - Rules: Negative values represent debits (withdrawals, payments, fees), positive values represent credits (deposits, refunds, interest)
#
# - currency (nvarchar)
#   - Description: ISO 4217 currency code for the transaction
#   - Valid Values: ZAR, USD, EUR, GBP, JPY
#   - Examples: ZAR, USD, EUR
#   - Rules: Primarily ZAR (85%), with some international currencies for forex transactions
#
# - description (nvarchar)
#   - Description: Human-readable description of the transaction
#   - Examples: Groceries purchase at Woolworths, Transfer to John Smith, Salary payment from ABC Corp
#   - Rules: Auto-generated based on transaction type and context
#
# - category (nvarchar)
#   - Description: Transaction category for spending analysis
#   - Valid Values: Groceries, Gas, Restaurant, Shopping, Utilities, Healthcare, Entertainment, Travel, Education, Insurance, Banking, Investment, Salary, Bonus, Refund, Other
#   - Examples: Groceries, Gas, Restaurant
#   - Rules: Used for budgeting and spending pattern analysis
#
# - channel (nvarchar)
#   - Description: Channel through which the transaction was made
#   - Valid Values: ATM, Online Banking, Mobile App, Branch, POS Terminal, Wire Transfer, ACH, Check, Direct Deposit
#   - Examples: ATM, Online Banking, Mobile App
#   - Rules: Tracks customer behavior and channel preference
#
# - status (nvarchar)
#   - Description: Current status of the transaction
#   - Valid Values: Completed, Pending, Failed, Cancelled
#   - Examples: Completed, Pending, Failed
#   - Rules: Only Completed transactions affect account balance
#
# - reference_number (nvarchar)
#   - Description: Unique reference number for transaction tracking
#   - Examples: REF1234AB5678, REF9876XY1234
#   - Rules: Used for transaction inquiries and dispute resolution
#   - Pattern: REF####?
#
# **Source:**
#  > Source (Doc id: cee79a9c-6724-492d-ac42-5b929f96fc39): <begin transaction history metadata>
#
# # Database Schema Information
#
# ## Database Details
# - *...
#
# **Source Metadata:**
# - {'category': 'transaction history table', 'year': '2025-07-20', 'department': 'Finance', 'author': 'Mzwandile Mhlongo', 'confidentiality': 'high', 'description': 'Comprehensive transaction history table containing all customer financial transactions including deposits, withdrawals, transfers, payments, and purchases'}
# [Trace(trace_id=3ebbdcb7f8e745b9829b58e0561bc5c8), Trace(trace_id=d76bc89d472c4dcf989ce5215376d2e6)]

# %%
generate_response("generate the full metadata for the following tables without intepreting or editing anything: [transaction_history, customer_information ]")
# Out:
# 2025-11-01 11:48:58,262 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# **Query:**
#  generate the full metadata for the following tables without intepreting or editing anything: [transaction_history, customer_information ]
#
# **Answer:**
#  Empty Response
#
# **Source:**
#
#
# **Source Metadata:**

# %% [markdown]
# # Index Bank Products Catalog
# ## Create ChromaDB Collection for Products
#
# This section indexes the bank products catalog and persists it to ChromaDB with the collection name "products".

# %%
# Define file path for bank products catalog
products_file_path = r"../documents/bank_products_services.txt"

# Verify file exists
import os
if os.path.exists(products_file_path):
    print(f"✅ Products file found: {products_file_path}")
    with open(products_file_path, 'r', encoding='utf-8') as f:
        content = f.read()
        print(f"📄 File size: {len(content)} characters")
        print(f"📄 Preview (first 500 chars):\n{content[:500]}...")
else:
    print(f"❌ Products file not found: {products_file_path}")
    print("Please ensure the bank_products_services.txt file exists in the documents folder")
# Out:
# ✅ Products file found: ../documents/bank_products_services.txt
# 📄 File size: 18596 characters
# 📄 Preview (first 500 chars):
# # Bank Products and Services Catalog
# ## Comprehensive Guide to Our Financial Products
#
# Last Updated: November 1, 2025
# Department: Product Management
# Classification: Public
#
# ---
#
# ## SAVINGS ACCOUNTS
#
# ### 1. Essential Savings Account
# **Product Code:** SAV-001
# **Description:** Basic savings account for everyday banking needs
#
# **Eligibility Criteria:**
# - Minimum Age: 18 years
# - Income Requirement: None
# - Credit Score: Not required
# - Employment Status: Any (students, employed, self-employed, unemploy...

# %%
# Create metadata function for bank products
def get_products_metadata(file_path):
    """
    Define metadata for bank products catalog
    """
    return {
        "category": "bank_products_catalog",
        "year": "2025",
        "department": "Product Management",
        "author": "Product Team",
        "confidentiality": "public",
        "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products",
        "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts",
        "last_updated": "2025-11-01"
    }

# Load the products document with metadata
products_documents = SimpleDirectoryReader(
    input_files=[products_file_path],
    file_metadata=lambda fp: get_products_metadata(fp)
).load_data()

print(f"✅ Loaded {len(products_documents)} document(s)")
print(f"📊 Document metadata: {products_documents[0].metadata if products_documents else 'N/A'}")
# Out:
# ✅ Loaded 1 document(s)
# 📊 Document metadata: {'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}

# %%
# Initialize ChromaDB client for products collection
products_index_path = r"../index/chroma_db"
products_db = chromadb.PersistentClient(path=products_index_path)

# Create or get the products collection
print("🔄 Creating 'products' collection...")
try:
    # Try to delete existing collection if it exists
    products_db.delete_collection("products")
    print("🗑️  Deleted existing 'products' collection")
except:
    print("ℹ️  No existing 'products' collection to delete")

# Create new products collection
products_collection = products_db.create_collection("products")
print(f"✅ Created new 'products' collection")

# Set up vector store and storage context
products_vector_store = ChromaVectorStore(chroma_collection=products_collection)
products_storage_context = StorageContext.from_defaults(vector_store=products_vector_store)

print("✅ ChromaDB vector store configured for products")
# Out:
# 🔄 Creating 'products' collection...
# 🗑️  Deleted existing 'products' collection
# ✅ Created new 'products' collection
# ✅ ChromaDB vector store configured for products

# %%
# Create and persist the products index
print("🔨 Building products vector index...")
print("⏳ This may take a few moments as we embed the products catalog...")

products_index = VectorStoreIndex.from_documents(
    products_documents,
    storage_context=products_storage_context,
    show_progress=True
)

print("✅ Products index created and persisted successfully!")
print(f"📁 Index location: {products_index_path}")
print(f"📦 Collection name: products")
print(f"🔢 Total documents indexed: {len(products_documents)}")
# Out:
# 🔨 Building products vector index...
# ⏳ This may take a few moments as we embed the products catalog...
# Parsing nodes: 100%|██████████| 1/1 [00:00<00:00, 72.74it/s]
# Parsing nodes: 100%|██████████| 1/1 [00:00<00:00, 72.74it/s]
# Generating embeddings:   0%|          | 0/7 [00:00<?, ?it/s]2025-11-01 08:22:17,516 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-11-01 08:22:17,516 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Generating embeddings: 100%|██████████| 7/7 [00:01<00:00,  5.00it/s]
# ✅ Products index created and persisted successfully!
# 📁 Index location: ../index/chroma_db
# 📦 Collection name: products
# 🔢 Total documents indexed: 1

# %%
# Verify the products collection was created
print("🔍 Verifying products collection...")

# List all collections in the database
all_collections = products_db.list_collections()
print(f"\n📋 All collections in database:")
for col in all_collections:
    print(f"  - {col.name} ({col.count()} items)")

# Check products collection specifically
products_collection_check = products_db.get_collection("products")
print(f"\n✅ Products collection verified:")
print(f"  - Name: {products_collection_check.name}")
print(f"  - Item count: {products_collection_check.count()}")

# Peek at first few items
if products_collection_check.count() > 0:
    sample = products_collection_check.peek(limit=3)
    print(f"\n📄 Sample from products collection (first 3 items):")
    for i, doc in enumerate(sample['documents'][:3]):
        print(f"\n  Item {i+1}:")
        print(f"    ID: {sample['ids'][i]}")
        print(f"    Document preview: {doc[:200]}...")
        if sample.get('metadatas') and sample['metadatas'][i]:
            print(f"    Metadata: {sample['metadatas'][i]}")
else:
    print("⚠️ Products collection is empty!")
# Out:
# 🔍 Verifying products collection...
#
# 📋 All collections in database:
#   - sql_tables_metadata (14 items)
#   - products (7 items)
#
# ✅ Products collection verified:
#   - Name: products
#   - Item count: 7
#
# 📄 Sample from products collection (first 3 items):
#
#   Item 1:
#     ID: 75961986-86cd-459a-a2a8-bcc03a477eeb
#     Document preview: # Bank Products and Services Catalog
# ## Comprehensive Guide to Our Financial Products
#
# Last Updated: November 1, 2025
# Department: Product Management
# Classification: Public
#
# ---
#
# ## SAVINGS ACCOUNTS
#
# #...
#     Metadata: {'category': 'bank_products_catalog', 'department': 'Product Management', '_node_type': 'TextNode', 'document_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', 'last_updated': '2025-11-01', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', '_node_content': '{"id_": "75961986-86cd-459a-a2a8-bcc03a477eeb", "embedding": null, "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "excluded_embed_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "excluded_llm_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "relationships": {"1": {"node_id": "de680805-6173-40c9-aeb4-ef440bffff8f", "node_type": "4", "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "hash": "a1dca7207f286e6773cac444d0e659e20a49cae8f52ec4808972fed233456f42", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "4943ccee-e510-48fa-94aa-f2062d221557", "node_type": "1", "metadata": {}, "hash": "8b8d72f5fc5a166bf1ce3c791dafefb94bd874cf33b01cbe34ce0e5d9d54a886", "class_name": "RelatedNodeInfo"}}, "metadata_template": "{key}: {value}", "metadata_separator": "\\n", "text": "", "mimetype": "text/plain", "start_char_idx": 0, "end_char_idx": 3059, "metadata_seperator": "\\n", "text_template": "{metadata_str}\\n\\n{content}", "class_name": "TextNode"}', 'year': '2025', 'ref_doc_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', 'confidentiality': 'public', 'author': 'Product Team', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'doc_id': 'de680805-6173-40c9-aeb4-ef440bffff8f'}
#
#   Item 2:
#     ID: 4943ccee-e510-48fa-94aa-f2062d221557
#     Document preview: Basic Checking Account
# **Product Code:** CHK-001
# **Description:** No-frills checking account for everyday transactions
#
# **Eligibility Criteria:**
# - Minimum Age: 18 years
# - Income Requirement: None
# - C...
#     Metadata: {'author': 'Product Team', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'doc_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', 'ref_doc_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', 'category': 'bank_products_catalog', 'department': 'Product Management', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'year': '2025', '_node_type': 'TextNode', '_node_content': '{"id_": "4943ccee-e510-48fa-94aa-f2062d221557", "embedding": null, "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "excluded_embed_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "excluded_llm_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "relationships": {"1": {"node_id": "de680805-6173-40c9-aeb4-ef440bffff8f", "node_type": "4", "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "hash": "a1dca7207f286e6773cac444d0e659e20a49cae8f52ec4808972fed233456f42", "class_name": "RelatedNodeInfo"}, "2": {"node_id": "75961986-86cd-459a-a2a8-bcc03a477eeb", "node_type": "1", "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "hash": "dc57749e9b92cabeb6df9ec825f7912e1c921e17d477223cf9bbf7cadae04e94", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "c8eddfe1-e33b-4eb3-bf44-1f7c0d893ee5", "node_type": "1", "metadata": {}, "hash": "013cfc9c95e1865a66585f574c3d76b367a4246d97539279febcfc7ca9b36be8", "class_name": "RelatedNodeInfo"}}, "metadata_template": "{key}: {value}", "metadata_separator": "\\n", "text": "", "mimetype": "text/plain", "start_char_idx": 2363, "end_char_idx": 5483, "metadata_seperator": "\\n", "text_template": "{metadata_str}\\n\\n{content}", "class_name": "TextNode"}', 'confidentiality': 'public', 'document_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', 'last_updated': '2025-11-01'}
#
#   Item 3:
#     ID: c8eddfe1-e33b-4eb3-bf44-1f7c0d893ee5
#     Document preview: Premium Travel Credit Card
# **Product Code:** CC-003
# **Description:** Elite travel rewards card with luxury perks
#
# **Eligibility Criteria:**
# - Minimum Age: 25 years
# - Income Requirement: $75,000 annual...
#     Metadata: {'confidentiality': 'public', 'department': 'Product Management', 'document_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', 'category': 'bank_products_catalog', 'doc_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', '_node_content': '{"id_": "c8eddfe1-e33b-4eb3-bf44-1f7c0d893ee5", "embedding": null, "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "excluded_embed_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "excluded_llm_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "relationships": {"1": {"node_id": "de680805-6173-40c9-aeb4-ef440bffff8f", "node_type": "4", "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "hash": "a1dca7207f286e6773cac444d0e659e20a49cae8f52ec4808972fed233456f42", "class_name": "RelatedNodeInfo"}, "2": {"node_id": "4943ccee-e510-48fa-94aa-f2062d221557", "node_type": "1", "metadata": {"category": "bank_products_catalog", "year": "2025", "department": "Product Management", "author": "Product Team", "confidentiality": "public", "description": "Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products", "product_categories": "savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts", "last_updated": "2025-11-01"}, "hash": "e9b26098ed948a386f99a7efdafa5e22917d3e1a851e92213156f5682028bdc8", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "d924ba44-3648-4524-847e-7b387032f678", "node_type": "1", "metadata": {}, "hash": "a86d034284e80b3bd34e166fd7dea382de82a4ec02806420381b2c42d8fe20b7", "class_name": "RelatedNodeInfo"}}, "metadata_template": "{key}: {value}", "metadata_separator": "\\n", "text": "", "mimetype": "text/plain", "start_char_idx": 5484, "end_char_idx": 8499, "metadata_seperator": "\\n", "text_template": "{metadata_str}\\n\\n{content}", "class_name": "TextNode"}', 'ref_doc_id': 'de680805-6173-40c9-aeb4-ef440bffff8f', '_node_type': 'TextNode', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'last_updated': '2025-11-01', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'author': 'Product Team', 'year': '2025'}

# %% [markdown]
# ## Test Products Query Engine
#
# Now let's test querying the products collection to ensure it works correctly.

# %%
# Create a query engine for products
products_query_engine = products_index.as_query_engine(similarity_top_k=5)

print("✅ Products query engine created")
print("🔍 Ready to query bank products!")
# Out:
# ✅ Products query engine created
# 🔍 Ready to query bank products!

# %%
# Helper function to query products
def query_products(query_text):
    """
    Query the products collection and display results
    """
    print(f"\n{'='*80}")
    print(f"🔍 QUERY: {query_text}")
    print(f"{'='*80}\n")
    
    response = products_query_engine.query(query_text)
    
    print("📝 ANSWER:")
    print(response)
    
    print(f"\n{'='*80}")
    print("📚 SOURCES:")
    print(response.get_formatted_sources())
    
    # Show source metadata
    if hasattr(response, 'source_nodes') and response.source_nodes:
        print(f"\n{'='*80}")
        print("📊 SOURCE METADATA & RELEVANCE:")
        for i, node in enumerate(response.source_nodes[:3], 1):
            print(f"\n  Source {i}:")
            print(f"    Relevance Score: {node.score:.4f}")
            if hasattr(node, 'metadata') and node.metadata:
                print(f"    Metadata: {node.metadata}")
            print(f"    Text Preview: {node.text[:200]}...")
    
    print(f"\n{'='*80}\n")
    
    return response

# %%
# Test Query 1: Savings account query
query_products("I make $45,000 per year and want to open a savings account with good interest rates. What options do I have?")
# Out:
# ================================================================================
# 🔍 QUERY: I make $45,000 per year and want to open a savings account with good interest rates. What options do I have?
# ================================================================================
# 2025-11-01 08:22:40,863 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-11-01 08:23:39,032 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 08:23:39,032 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 📝 ANSWER:
# You have several savings options that fit a $45,000 annual income. Which is best depends on how much you’ll deposit, whether you need frequent access to funds, and your credit score. Summary of the strongest options:
#
# 1. Premium Savings Account (SAV-002)
# - Eligibility: age 21+, $30,000+ annual income, credit score 650+, employed or self‑employed with verifiable income.
# - Key points: $1,000 minimum to open; $2,500 minimum monthly balance; APY 4.25%; $15 monthly fee (waived with >$5,000); unlimited free ATM; premium features and quarterly interest bonuses for balances >$10,000.
# - Best if: you meet the credit/age requirements and want one of the highest APYs without locking funds.
#
# 2. Money Market Account (MMA-001)
# - Eligibility: age 18+, no income or credit requirement.
# - Key points: $2,500 minimum opening and to earn interest; tiered APY:
#   - $2,500–$9,999: 3.00%
#   - $10,000–$24,999: 3.50%
#   - $25,000–$99,999: 4.00%
#   - $100,000+: 4.50%
#   $12 monthly fee (waived with $10,000); check-writing (6/mo), debit card, 6 free transfers/mo.
# - Best if: you want higher yield plus liquidity and check-writing; yields are competitive if you can maintain $25k+ (and top out at 4.50% for $100k+).
#
# 3. Essential Savings Account (SAV-001)
# - Key points: $25 minimum to open; APY 0.50%; $5 monthly fee (waived if balance > $500).
# - Best if: you need a low-barrier account for short-term saving or don’t meet requirements for premium products.
#
# 4. Certificate of Deposit (CD-001) — if you’re willing to lock funds
# - Key points: $1,000 minimum; terms from 3 to 60 months; APYs up to 4.50% (highest for 60-month term); early withdrawal penalties apply.
# - Best if: you don’t need immediate access and want a higher guaranteed rate.
#
# Recommendation steps
# - If you meet the age and credit requirements and can keep at least $2,500 in the account, the Premium Savings account is the strongest everyday savings option (4.25% APY).
# - If you value check-writing and have $10k–$25k (or more), consider the Money Market for liquidity and competitive tiered yields; it becomes especially attractive at $25k+ and best at $100k+.
# - If you can lock funds for a term, compare CD terms for potentially higher fixed APYs.
#
# If you want, tell me how much you plan to deposit and whether you need regular access to funds (check-writing/ATM), and I’ll recommend the single best option and next steps to apply.
#
# ================================================================================
# 📚 SOURCES:
# > Source (Doc id: 6c132099-5f58-41cb-9946-55aa58c3efc1): Money Market Account
# **Product Code:** MMA-001
# **Description:** High-yield savings account with c...
#
# > Source (Doc id: 75961986-86cd-459a-a2a8-bcc03a477eeb): # Bank Products and Services Catalog
# ## Comprehensive Guide to Our Financial Products
#
# Last Updat...
#
# > Source (Doc id: 5ce354a8-4604-4da5-b569-a4985686285a): 529 College Savings Plan
# **Product Code:** EDU-001
# **Description:** Tax-advantaged investment acc...
#
# > Source (Doc id: 0ecb68a9-5631-4485-b396-185d9025c129): Used Car Loan
# **Product Code:** AUTO-002
# **Description:** Financing for pre-owned vehicle purchas...
#
# > Source (Doc id: 4943ccee-e510-48fa-94aa-f2062d221557): Basic Checking Account
# **Product Code:** CHK-001
# **Description:** No-frills checking account for ...
#
# ================================================================================
# 📊 SOURCE METADATA & RELEVANCE:
#
#   Source 1:
#     Relevance Score: 0.3211
#     Metadata: {'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}
#     Text Preview: Money Market Account
# **Product Code:** MMA-001
# **Description:** High-yield savings account with check-writing privileges
#
# **Eligibility Criteria:**
# - Minimum Age: 18 years
# - Income Requirement: None
# -...
#
#   Source 2:
#     Relevance Score: 0.2924
#     Metadata: {'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}
#     Text Preview: # Bank Products and Services Catalog
# ## Comprehensive Guide to Our Financial Products
#
# Last Updated: November 1, 2025
# Department: Product Management
# Classification: Public
#
# ---
#
# ## SAVINGS ACCOUNTS
#
# #...
#
#   Source 3:
#     Relevance Score: 0.2871
#     Metadata: {'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}
#     Text Preview: 529 College Savings Plan
# **Product Code:** EDU-001
# **Description:** Tax-advantaged investment account for education expenses
#
# **Eligibility Criteria:**
# - Account Owner: Any age, any state resident
# - B...
#
# ================================================================================
# Response(response='You have several savings options that fit a $45,000 annual income. Which is best depends on how much you’ll deposit, whether you need frequent access to funds, and your credit score. Summary of the strongest options:\n\n1. Premium Savings Account (SAV-002)\n- Eligibility: age 21+, $30,000+ annual income, credit score 650+, employed or self‑employed with verifiable income.  \n- Key points: $1,000 minimum to open; $2,500 minimum monthly balance; APY 4.25%; $15 monthly fee (waived with >$5,000); unlimited free ATM; premium features and quarterly interest bonuses for balances >$10,000.  \n- Best if: you meet the credit/age requirements and want one of the highest APYs without locking funds.\n\n2. Money Market Account (MMA-001)\n- Eligibility: age 18+, no income or credit requirement.  \n- Key points: $2,500 minimum opening and to earn interest; tiered APY:\n  - $2,500–$9,999: 3.00%\n  - $10,000–$24,999: 3.50%\n  - $25,000–$99,999: 4.00%\n  - $100,000+: 4.50%\n  $12 monthly fee (waived with $10,000); check-writing (6/mo), debit card, 6 free transfers/mo.  \n- Best if: you want higher yield plus liquidity and check-writing; yields are competitive if you can maintain $25k+ (and top out at 4.50% for $100k+).\n\n3. Essential Savings Account (SAV-001)\n- Key points: $25 minimum to open; APY 0.50%; $5 monthly fee (waived if balance > $500).  \n- Best if: you need a low-barrier account for short-term saving or don’t meet requirements for premium products.\n\n4. Certificate of Deposit (CD-001) — if you’re willing to lock funds\n- Key points: $1,000 minimum; terms from 3 to 60 months; APYs up to 4.50% (highest for 60-month term); early withdrawal penalties apply.  \n- Best if: you don’t need immediate access and want a higher guaranteed rate.\n\nRecommendation steps\n- If you meet the age and credit requirements and can keep at least $2,500 in the account, the Premium Savings account is the strongest everyday savings option (4.25% APY).  \n- If you value check-writing and have $10k–$25k (or more), consider the Money Market for liquidity and competitive tiered yields; it becomes especially attractive at $25k+ and best at $100k+.  \n- If you can lock funds for a term, compare CD terms for potentially higher fixed APYs.\n\nIf you want, tell me how much you plan to deposit and whether you need regular access to funds (check-writing/ATM), and I’ll recommend the single best option and next steps to apply.', source_nodes=[NodeWithScore(node=TextNode(id_='6c132099-5f58-41cb-9946-55aa58c3efc1', embedding=None, metadata={'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='de680805-6173-40c9-aeb4-ef440bffff8f', node_type='4', metadata={'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}, ha ...

# %%
# Test Query 2: Credit card query
query_products("What credit cards are available for someone with a 680 credit score?")
# Out:
# ================================================================================
# 🔍 QUERY: What credit cards are available for someone with a 680 credit score?
# ================================================================================
# 2025-11-01 08:23:39,642 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-11-01 08:23:54,807 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 08:23:54,807 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 📝 ANSWER:
# You qualify for the Rewards Credit Card (CC-002).
#
# Key eligibility (high-level)
# - Minimum age: 21
# - Income: $35,000 annually
# - Credit score: 670–739 (your 680 falls in this range)
# - Employment: Employed or self‑employed
#
# Key features
# - Credit limit: $3,000–$15,000
# - Annual fee: $95 (waived first year)
# - APR: 15.99%–21.99% variable
# - Cash advance fee: 5% or $10 (whichever is greater)
# - Late payment fee: $40
# - Foreign transaction fee: 0%
# - Rewards: 3% cashback on groceries, 2% on gas, 1% on other purchases
# - Sign‑up bonus: $200 after spending $1,000 in first 3 months
# - Purchase protection: 90 days; extended warranty: additional 1 year
#
# Notes
# - The Premium Travel Card (CC-003) requires a higher credit score (740+).
# - The Starter Card (CC-001) is targeted at lower scores (580–669).
#
# ================================================================================
# 📚 SOURCES:
# > Source (Doc id: c8eddfe1-e33b-4eb3-bf44-1f7c0d893ee5): Premium Travel Credit Card
# **Product Code:** CC-003
# **Description:** Elite travel rewards card wi...
#
# > Source (Doc id: 4943ccee-e510-48fa-94aa-f2062d221557): Basic Checking Account
# **Product Code:** CHK-001
# **Description:** No-frills checking account for ...
#
# > Source (Doc id: d924ba44-3648-4524-847e-7b387032f678): First-Time Homebuyer Mortgage
# **Product Code:** MTG-001
# **Description:** Special mortgage program...
#
# > Source (Doc id: 0ecb68a9-5631-4485-b396-185d9025c129): Used Car Loan
# **Product Code:** AUTO-002
# **Description:** Financing for pre-owned vehicle purchas...
#
# > Source (Doc id: 6c132099-5f58-41cb-9946-55aa58c3efc1): Money Market Account
# **Product Code:** MMA-001
# **Description:** High-yield savings account with c...
#
# ================================================================================
# 📊 SOURCE METADATA & RELEVANCE:
#
#   Source 1:
#     Relevance Score: 0.2994
#     Metadata: {'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}
#     Text Preview: Premium Travel Credit Card
# **Product Code:** CC-003
# **Description:** Elite travel rewards card with luxury perks
#
# **Eligibility Criteria:**
# - Minimum Age: 25 years
# - Income Requirement: $75,000 annual...
#
#   Source 2:
#     Relevance Score: 0.2976
#     Metadata: {'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}
#     Text Preview: Basic Checking Account
# **Product Code:** CHK-001
# **Description:** No-frills checking account for everyday transactions
#
# **Eligibility Criteria:**
# - Minimum Age: 18 years
# - Income Requirement: None
# - C...
#
#   Source 3:
#     Relevance Score: 0.2550
#     Metadata: {'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}
#     Text Preview: First-Time Homebuyer Mortgage
# **Product Code:** MTG-001
# **Description:** Special mortgage program for first-time homebuyers
#
# **Eligibility Criteria:**
# - Minimum Age: 21 years
# - Income Requirement: $40...
#
# ================================================================================
# Response(response='You qualify for the Rewards Credit Card (CC-002).\n\nKey eligibility (high-level)\n- Minimum age: 21\n- Income: $35,000 annually\n- Credit score: 670–739 (your 680 falls in this range)\n- Employment: Employed or self‑employed\n\nKey features\n- Credit limit: $3,000–$15,000\n- Annual fee: $95 (waived first year)\n- APR: 15.99%–21.99% variable\n- Cash advance fee: 5% or $10 (whichever is greater)\n- Late payment fee: $40\n- Foreign transaction fee: 0%\n- Rewards: 3% cashback on groceries, 2% on gas, 1% on other purchases\n- Sign‑up bonus: $200 after spending $1,000 in first 3 months\n- Purchase protection: 90 days; extended warranty: additional 1 year\n\nNotes\n- The Premium Travel Card (CC-003) requires a higher credit score (740+).\n- The Starter Card (CC-001) is targeted at lower scores (580–669).', source_nodes=[NodeWithScore(node=TextNode(id_='c8eddfe1-e33b-4eb3-bf44-1f7c0d893ee5', embedding=None, metadata={'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='de680805-6173-40c9-aeb4-ef440bffff8f', node_type='4', metadata={'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}, hash='a1dca7207f286e6773cac444d0e659e20a49cae8f52ec4808972fed233456f42'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='4943ccee-e510-48fa-94aa-f2062d221557', node_type='1', metadata={'category': 'bank_products_catalog', 'year': '2025', 'department': 'Product Management', 'author': 'Product Team', 'confidentiality': 'public', 'description': 'Comprehensive bank products and services catalog including savings accounts, checking accounts, credit cards, loans, mortgages, and investment products', 'product_categories': 'savings_accounts, checking_accounts, credit_cards, personal_loans, home_loans, auto_loans, business_accounts, investment_products, specialty_accounts', 'last_updated': '2025-11-01'}, hash='e9b26098ed948a386f99a7efdafa5e22917d3e1a851e92213156f5682028bdc8'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='d924ba44-3648-4524-847e-7b387032f678', node_type='1', metadata={}, hash='a86d034284e80b3bd34e166fd7dea382de82a4ec02806420381b2c42d8fe20b7')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Premium Travel Credit Card\n**Product Code:** CC-003\n**Description:** Elite travel rewards card with luxury perks\n\n**Eligibility Criteria:**\n- Minimum Age: 25 years\n- Income Requirement: $75,000 annually\n- Credit Score: 740+ (Excellent credit)\n- Employment Status: Employed or Self-employed\n\n**Key Features:**\n- Credit Limit: $10,000 - $50,000\n- Annual Fee: $495\n- APR: 14.99% - 18.99% variable\n- Cash Advance Fee: 5% or $10, whichever is greater\n- Late Payment Fee: $40\n- Foreign Transaction Fee: 0%\n- Rewards:\n  - 5x points on flights and hotels\n ...

# %%
# Test Query 3: Business account query
query_products("I'm starting a small business and need a business checking account")

# %% [markdown]
# ## Load Products from Persisted Index
#
# This section shows how to load the products collection from the persisted ChromaDB index in future sessions.

# %%
# Load products index from persisted ChromaDB
# Use this in future sessions to query without re-indexing

# Initialize client
products_db_load = chromadb.PersistentClient(path=r"../index/chroma_db")

# Get the products collection
products_collection_load = products_db_load.get_collection("products")

print(f"✅ Loaded products collection")
print(f"  - Collection name: {products_collection_load.name}")
print(f"  - Item count: {products_collection_load.count()}")

# Create vector store and load index
products_vector_store_load = ChromaVectorStore(chroma_collection=products_collection_load)
products_storage_context_load = StorageContext.from_defaults(vector_store=products_vector_store_load)

# Load index from vector store
products_index_load = VectorStoreIndex.from_vector_store(
    products_vector_store_load,
    storage_context=products_storage_context_load
)

# Create query engine
products_query_engine_load = products_index_load.as_query_engine(similarity_top_k=5)

print("✅ Products query engine loaded from persisted index")
print("🔍 Ready to query!")

# %%
# Test query from loaded index
response = products_query_engine_load.query("What mortgage options are available for first-time homebuyers?")

print("\n🔍 Query: What mortgage options are available for first-time homebuyers?")
print("\n📝 Answer:")
print(response)
